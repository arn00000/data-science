# %% [markdown]
# <img src="https://i.imgur.com/FoKB5Z5.png" align="left" width="300" height="250" title="source: imgur.com" /></a>

# %% [markdown]
# ## Program Code: J620-002-4:2020
#
# ## Program Name: FRONT-END SOFTWARE DEVELOPMENT
#
# ## Title :  Case Study - IMDB Web Scraping
#
# #### Name: Ooi Caaron
#
# #### IC Number: 990701-07-5837
#
# #### Date : 7/7/23
#
# #### Introduction : First question is the hardest part when scrapping the data from the web and put it to seperate columns
#
#
#
# #### Conclusion : Still need to practice more and do revision

# %% [markdown]
# **Reference : https://medium.com/better-programming/the-only-step-by-step-guide-youll-need-to-build-a-web-scraper-with-python-e79066bd895a**

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver

# %% [markdown]
# ## 1. Import Data by using webscrapping
# Open the URL with headless webdriver and parse the page source into html with beautifulsoup

# %%
import time
url = 'https://www.imdb.com/search/title/?groups=top_1000&ref_=adv_prvt'
driver = webdriver.Chrome('C://GoogleDriver//chromedriver')
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %% [markdown]
# Append data found into list according to the category

# %%
data = []
for page in range(1, 21):
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    lists = soup.find_all("div", class_="lister-item-content")
    for list in lists:
        row_data = {
            'Rank': '',
            'Title': '',
            'Year': '',
            'PG': '',
            'Runtime': '',
            'Genre': '',
            'IMDB_Rating': '',
            'Metascore': '',
            'Director': '',
            'Stars': '',
            'Description': '',
            'Votes': '',
            'Gross': ''
        }
        rank = list.find("span", attrs={"class":"lister-item-index"}).text.strip()
        title = list.find("a").text.strip()
        year = list.find("span", attrs={"class":"lister-item-year"}).text.strip()
        pg = list.find("span", attrs={"class":"certificate"})
        if pg is not None:
            pg = pg.text.strip()
        else:
            pg = "Not Rated"
        runtime = list.find("span", attrs={"class":"runtime"}).text.strip()
        genre = list.find("span", attrs={"class":"genre"}).text.strip()
        imdb_rating = list.find("strong").text.strip()
        metascore = list.find("span", attrs={"class":"metascore"})
        if metascore is not None:
            metascore = metascore.text.strip()
        else:
            metascore = '0'
        description = list.findAll("p", attrs={"class":"text-muted"})[1].text.strip()
        director = list.find_all("a", href=True)
        director = [tag.text for tag in director if tag.get("href") and "adv_li_dr_" in tag.get("href")]
        stars = list.find_all("a", href=True)
        stars = [tag.text for tag in stars if tag.get("href") and "adv_li_st_" in tag.get("href")]
        votes = list.findAll("span", attrs={"name":"nv"})[0].text
        gross = list.findAll("span", attrs={"name": "nv"})
        gross = gross[1].text.strip() if len(gross) > 1 else 0
        row_data['Rank'] = rank
        row_data['Title'] = title
        row_data['Year'] = year
        row_data['PG'] = pg
        row_data['Runtime'] = runtime
        row_data['Genre'] = genre
        row_data['IMDB_Rating'] = imdb_rating
        row_data['Metascore'] = metascore
        row_data['Director'] = director
        row_data['Stars'] = stars
        row_data['Description'] = description
        row_data['Votes'] = votes
        row_data['Gross'] = gross
        data.append(row_data)
    if page == 1:
        next_button = driver.find_element_by_xpath('/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[4]/a')
        next_button.click()
    else:
        if page < 20:
            next_button = driver.find_element_by_xpath('/html/body/div[2]/div/div[2]/div[3]/div[1]/div/div[4]/a[2]')
            next_button.click()
#     time.sleep(2) 
        
data
# Out:
# [{'Rank': '1.',
#   'Title': 'Spider-Man: Across the Spider-Verse',
#   'Year': '(2023)',
#   'PG': 'PG',
#   'Runtime': '140 min',
#   'Genre': 'Animation, Action, Adventure',
#   'IMDB_Rating': '8.9',
#   'Metascore': '86',
#   'Director': ['Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson'],
#   'Stars': ['Shameik Moore',
#    'Hailee Steinfeld',
#    'Brian Tyree Henry',
#    'Luna Lauren Velez'],
#   'Description': 'Miles Morales catapults across the Multiverse, where he encounters a team of Spider-People charged with protecting its very existence. When the heroes clash on how to handle a new threat, Miles must redefine what it means to be a hero.',
#   'Votes': '171,148',
#   'Gross': '#12'},
#  {'Rank': '2.',
#   'Title': 'Titanic',
#   'Year': '(1997)',
#   'PG': 'PG-13',
#   'Runtime': '194 min',
#   'Genre': 'Drama, Romance',
#   'IMDB_Rating': '7.9',
#   'Metascore': '75',
#   'Director': ['James Cameron'],
#   'Stars': ['Leonardo DiCaprio', 'Kate Winslet', 'Billy Zane', 'Kathy Bates'],
#   'Description': 'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.',
#   'Votes': '1,228,477',
#   'Gross': '$659.33M'},
#  {'Rank': '3.',
#   'Title': 'Avatar: The Way of Water',
#   'Year': '(2022)',
#   'PG': 'PG-13',
#   'Runtime': '192 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '7.6',
#   'Metascore': '67',
#   'Director': ['James Cameron'],
#   'Stars': ['Sam Worthington',
#    'Zoe Saldana',
#    'Sigourney Weaver',
#    'Stephen Lang'],
#   'Description': "Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.",
#   'Votes': '425,970',
#   'Gross': '$659.68M'},
#  {'Rank': '4.',
#   'Title': 'John Wick: Chapter 4',
#   'Year': '(2023)',
#   'PG': 'R',
#   'Runtime': '169 min',
#   'Genre': 'Action, Crime, Thriller',
#   'IMDB_Rating': '7.9',
#   'Metascore': '78',
#   'Director': ['Chad Stahelski'],
#   'Stars': ['Keanu Reeves',
#    'Laurence Fishburne',
#    'George Georgiou',
#    'Lance Reddick'],
#   'Description': 'John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.',
#   'Votes': '232,446',
#   'Gross': 0},
#  {'Rank': '5.',
#   'Title': 'Indiana Jones and the Raiders of the Lost Ark',
#   'Year': '(1981)',
#   'PG': 'PG',
#   'Runtime': '115 min',
#   'Genre': 'Action, Adventure',
#   'IMDB_Rating': '8.4',
#   'Metascore': '85',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Harrison Ford',
#    'Karen Allen',
#    'Paul Freeman',
#    'John Rhys-Davies'],
#   'Description': 'In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before the Nazis can obtain its awesome powers.',
#   'Votes': '998,751',
#   'Gross': '$248.16M'},
#  {'Rank': '6.',
#   'Title': 'Guardians of the Galaxy Vol. 3',
#   'Year': '(2023)',
#   'PG': 'PG-13',
#   'Runtime': '150 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '8.2',
#   'Metascore': '64',
#   'Director': ['James Gunn'],
#   'Stars': ['Chris Pratt',
#    'Chukwudi Iwuji',
#    'Bradley Cooper',
#    'Pom Klementieff'],
#   'Description': 'Still reeling from the loss of Gamora, Peter Quill rallies his team to defend the universe and one of their own - a mission that could mean the end of the Guardians if not successful.',
#   'Votes': '183,601',
#   'Gross': '#170'},
#  {'Rank': '7.',
#   'Title': 'Spider-Man: Into the Spider-Verse',
#   'Year': '(2018)',
#   'PG': 'PG',
#   'Runtime': '117 min',
#   'Genre': 'Animation, Action, Adventure',
#   'IMDB_Rating': '8.4',
#   'Metascore': '87',
#   'Director': ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman'],
#   'Stars': ['Shameik Moore',
#    'Jake Johnson',
#    'Hailee Steinfeld',
#    'Mahershala Ali'],
#   'Description': 'Teen Miles Morales becomes the Spider-Man of his universe and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.',
#   'Votes': '603,237',
#   'Gross': '$190.24M'},
#  {'Rank': '8.',
#   'Title': 'Indiana Jones and the Last Crusade',
#   'Year': '(1989)',
#   'PG': 'PG-13',
#   'Runtime': '127 min',
#   'Genre': 'Action, Adventure',
#   'IMDB_Rating': '8.2',
#   'Metascore': '65',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Harrison Ford',
#    'Sean Connery',
#    'Alison Doody',
#    'Denholm Elliott'],
#   'Description': 'In 1938, after his father goes missing while pursuing the Holy Grail, Indiana Jones finds himself up against the Nazis again to stop them from obtaining its powers.',
#   'Votes': '779,756',
#   'Gross': '$197.17M'},
#  {'Rank': '9.',
#   'Title': 'Pulp Fiction',
#   'Year': '(1994)',
#   'PG': 'R',
#   'Runtime': '154 min',
#   'Genre': 'Crime, Drama',
#   'IMDB_Rating': '8.9',
#   'Metascore': '95',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['John Travolta',
#    'Uma Thurman',
#    'Samuel L. Jackson',
#    'Bruce Willis'],
#   'Description': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.',
#   'Votes': '2,120,228',
#   'Gross': '$107.93M'},
#  {'Rank': '10.',
#   'Title': 'Interstellar',
#   'Year': '(2014)',
#   'PG': 'PG-13',
#   'Runtime': '169 min',
#   'Genre': 'Adventure, Drama, Sci-Fi',
#   'IMDB_Rating': '8.7',
#   'Metascore': '74',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Matthew McConaughey',
#    'Anne Hathaway',
#    'Jessica Chastain',
#    'Mackenzie Foy'],
#   'Description': 'When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.',
#   'Votes': '1,929,940',
#   'Gross': '$188.02M'},
#  {'Rank': '11.',
#   'Title': 'Dune',
#   'Year': '(2021)',
#   'PG': 'PG-13',
#   'Runtime': '155 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '74',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Timothée Chalamet', 'Rebecca Ferguson', 'Zendaya', 'Oscar Isaac'],
#   'Description': "A noble family becomes embroiled in a war for control over the galaxy's most valuable asset while its heir becomes troubled by visions of a dark future.",
#   'Votes': '689,224',
#   'Gross': '$108.33M'},
#  {'Rank': '12.',
#   'Title': 'Top Gun: Maverick',
#   'Year': '(2022)',
#   'PG': 'PG-13',
#   'Runtime': '130 min',
#   'Genre': 'Action, Drama',
#   'IMDB_Rating': '8.3',
#   'Metascore': '78',
#   'Director': ['Joseph Kosinski'],
#   'Stars': ['Tom Cruise', 'Jennifer Connelly', 'Miles Teller', 'Val Kilmer'],
#   'Description': "After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.",
#   'Votes': '604,132',
#   'Gross': '$718.73M'},
#  {'Rank': '13.',
#   'Title': 'The Shawshank Redemption',
#   'Year': '(1994)',
#   'PG': 'R',
#   'Runtime': '142 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '9.3',
#   'Metascore': '82',
#   'Director': ['Frank Darabont'],
#   'Stars': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler'],
#   'Description': 'Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.',
#   'Votes': '2,761,529',
#   'Gross': '$28.34M'},
#  {'Rank': '14.',
#   'Title': 'The Godfather',
#   'Year': '(1972)',
#   'PG': 'R',
#   'Runtime': '175 min',
#   'Genre': 'Crime, Drama',
#   'IMDB_Rating': '9.2',
#   'Metascore': '100',
#   'Director': ['Francis Ford Coppola'],
#   'Stars': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton'],
#   'Description': 'Don Vito Corleone, head of a mafia family, decides to hand over his empire to his youngest son Michael. However, his decision unintentionally puts the lives of his loved ones in grave danger.',
#   'Votes': '1,921,787',
#   'Gross': '$134.97M'},
#  {'Rank': '15.',
#   'Title': 'The Batman',
#   'Year': '(2022)',
#   'PG': 'PG-13',
#   'Runtime': '176 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '72',
#   'Director': ['Matt Reeves'],
#   'Stars': ['Robert Pattinson',
#    'Zoë Kravitz',
#    'Jeffrey Wright',
#    'Colin Farrell'],
#   'Description': "When a sadistic serial killer begins murdering key political figures in Gotham, Batman is forced to investigate the city's hidden corruption and question his family's involvement.",
#   'Votes': '708,217',
#   'Gross': '$369.35M'},
#  {'Rank': '16.',
#   'Title': 'Everything Everywhere All at Once',
#   'Year': '(2022)',
#   'PG': 'R',
#   'Runtime': '139 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '7.8',
#   'Metascore': '81',
#   'Director': ['Daniel Kwan', 'Daniel Scheinert'],
#   'Stars': ['Michelle Yeoh',
#    'Stephanie Hsu',
#    'Jamie Lee Curtis',
#    'Ke Huy Quan'],
#   'Description': 'A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.',
#   'Votes': '459,835',
#   'Gross': '$72.86M'},
#  {'Rank': '17.',
#   'Title': 'The Dark Knight',
#   'Year': '(2008)',
#   'PG': 'PG-13',
#   'Runtime': '152 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '9.0',
#   'Metascore': '84',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Christian Bale',
#    'Heath Ledger',
#    'Aaron Eckhart',
#    'Michael Caine'],
#   'Description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#   'Votes': '2,734,530',
#   'Gross': '$534.86M'},
#  {'Rank': '18.',
#   'Title': 'Avatar',
#   'Year': '(2009)',
#   'PG': 'PG-13',
#   'Runtime': '162 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '83',
#   'Director': ['James Cameron'],
#   'Stars': ['Sam Worthington',
#    'Zoe Saldana',
#    'Sigourney Weaver',
#    'Michelle Rodriguez'],
#   'Description': 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.',
#   'Votes': '1,351,165',
#   'Gross': '$760.51M'},
#  {'Rank': '19.',
#   'Title': 'Inception',
#   'Year': '(2010)',
#   'PG': 'PG-13',
#   'Runtime': '148 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.8',
#   'Metascore': '74',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Leonardo DiCaprio',
#    'Joseph Gordon-Levitt',
#    'Elliot Page',
#    'Ken Watanabe'],
#   'Description': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.',
#   'Votes': '2,426,691',
#   'Gross': '$292.58M'},
#  {'Rank': '20.',
#   'Title': "Harry Potter and the Sorcerer's Stone",
#   'Year': '(2001)',
#   'PG': 'PG',
#   'Runtime': '152 min',
#   'Genre': 'Adventure, Family, Fantasy',
#   'IMDB_Rating': '7.6',
#   'Metascore': '65',
#   'Director': ['Chris Columbus'],
#   'Stars': ['Daniel Radcliffe',
#    'Rupert Grint',
#    'Richard Harris',
#    'Maggie Smith'],
#   'Description': 'An orphaned boy enrolls in a school of wizardry, where he learns the truth about himself, his family and the terrible evil that haunts the magical world.',
#   'Votes': '814,077',
#   'Gross': '$317.58M'},
#  {'Rank': '21.',
#   'Title': 'The Wolf of Wall Street',
#   'Year': '(2013)',
#   'PG': 'R',
#   'Runtime': '180 min',
#   'Genre': 'Biography, Comedy, Crime',
#   'IMDB_Rating': '8.2',
#   'Metascore': '75',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Leonardo DiCaprio',
#    'Jonah Hill',
#    'Margot Robbie',
#    'Matthew McConaughey'],
#   'Description': 'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.',
#   'Votes': '1,473,923',
#   'Gross': '$116.90M'},
#  {'Rank': '22.',
#   'Title': 'Spider-Man: No Way Home',
#   'Year': '(2021)',
#   'PG': 'PG-13',
#   'Runtime': '148 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '8.2',
#   'Metascore': '71',
#   'Director': ['Jon Watts'],
#   'Stars': ['Tom Holland', 'Zendaya', 'Benedict Cumberbatch', 'Jacob Batalon'],
#   'Description': "With Spider-Man's identity now revealed, Peter asks Doctor Strange for help. When a spell goes wrong, dangerous foes from other worlds start to appear, forcing Peter to discover what it truly means to be Spider-Man.",
#   'Votes': '809,640',
#   'Gross': '$804.75M'},
#  {'Rank': '23.',
#   'Title': 'Once Upon a Time in Hollywood',
#   'Year': '(2019)',
#   'PG': 'R',
#   'Runtime': '161 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.6',
#   'Metascore': '83',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['Leonardo DiCaprio', 'Brad Pitt', 'Margot Robbie', 'Emile Hirsch'],
#   'Description': "A faded television actor and his stunt double strive to achieve fame and success in the final years of Hollywood's Golden Age in 1969 Los Angeles.",
#   'Votes': '783,964',
#   'Gross': '$142.50M'},
#  {'Rank': '24.',
#   'Title': 'The Whale',
#   'Year': '(2022)',
#   'PG': 'R',
#   'Runtime': '117 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '60',
#   'Director': ['Darren Aronofsky'],
#   'Stars': ['Brendan Fraser', 'Sadie Sink', 'Ty Simpkins', 'Hong Chau'],
#   'Description': 'A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.',
#   'Votes': '158,828',
#   'Gross': 0},
#  {'Rank': '25.',
#   'Title': 'Jaws',
#   'Year': '(1975)',
#   'PG': 'PG',
#   'Runtime': '124 min',
#   'Genre': 'Adventure, Mystery, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '87',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Roy Scheider',
#    'Robert Shaw',
#    'Richard Dreyfuss',
#    'Lorraine Gary'],
#   'Description': "When a killer shark unleashes chaos on a beach community off Cape Cod, it's up to a local sheriff, a marine biologist, and an old seafarer to hunt the beast down.",
#   'Votes': '628,699',
#   'Gross': '$260.00M'},
#  {'Rank': '26.',
#   'Title': 'Tombstone',
#   'Year': '(1993)',
#   'PG': 'R',
#   'Runtime': '130 min',
#   'Genre': 'Biography, Drama, History',
#   'IMDB_Rating': '7.8',
#   'Metascore': '50',
#   'Director': ['George P. Cosmatos', 'Kevin Jarre'],
#   'Stars': ['Kurt Russell', 'Val Kilmer', 'Sam Elliott', 'Bill Paxton'],
#   'Description': "A successful lawman's plans to retire anonymously in Tombstone, Arizona are disrupted by the kind of outlaws he was famous for eliminating.",
#   'Votes': '157,118',
#   'Gross': '$56.51M'},
#  {'Rank': '27.',
#   'Title': 'The Grand Budapest Hotel',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '99 min',
#   'Genre': 'Adventure, Comedy, Crime',
#   'IMDB_Rating': '8.1',
#   'Metascore': '88',
#   'Director': ['Wes Anderson'],
#   'Stars': ['Ralph Fiennes',
#    'F. Murray Abraham',
#    'Mathieu Amalric',
#    'Adrien Brody'],
#   'Description': "A writer encounters the owner of an aging high-class hotel, who tells him of his early years serving as a lobby boy in the hotel's glorious years under an exceptional concierge.",
#   'Votes': '844,469',
#   'Gross': '$59.10M'},
#  {'Rank': '28.',
#   'Title': 'There Will Be Blood',
#   'Year': '(2007)',
#   'PG': 'R',
#   'Runtime': '158 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.2',
#   'Metascore': '93',
#   'Director': ['Paul Thomas Anderson'],
#   'Stars': ['Daniel Day-Lewis',
#    'Paul Dano',
#    'Ciarán Hinds',
#    'Martin Stringer'],
#   'Description': 'A story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.',
#   'Votes': '607,246',
#   'Gross': '$40.22M'},
#  {'Rank': '29.',
#   'Title': 'Avengers: Endgame',
#   'Year': '(2019)',
#   'PG': 'PG-13',
#   'Runtime': '181 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.4',
#   'Metascore': '78',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Stars': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth'],
#   'Description': "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'Votes': '1,190,853',
#   'Gross': '$858.37M'},
#  {'Rank': '30.',
#   'Title': 'Django Unchained',
#   'Year': '(2012)',
#   'PG': 'R',
#   'Runtime': '165 min',
#   'Genre': 'Drama, Western',
#   'IMDB_Rating': '8.4',
#   'Metascore': '81',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['Jamie Foxx',
#    'Christoph Waltz',
#    'Leonardo DiCaprio',
#    'Kerry Washington'],
#   'Description': 'With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation owner in Mississippi.',
#   'Votes': '1,609,238',
#   'Gross': '$162.81M'},
#  {'Rank': '31.',
#   'Title': 'Mission: Impossible - Fallout',
#   'Year': '(2018)',
#   'PG': 'PG-13',
#   'Runtime': '147 min',
#   'Genre': 'Action, Adventure, Thriller',
#   'IMDB_Rating': '7.7',
#   'Metascore': '86',
#   'Director': ['Christopher McQuarrie'],
#   'Stars': ['Tom Cruise', 'Henry Cavill', 'Ving Rhames', 'Simon Pegg'],
#   'Description': 'Ethan Hunt and his IMF team, along with some familiar allies, race against time after a mission gone wrong.',
#   'Votes': '347,859',
#   'Gross': '$220.16M'},
#  {'Rank': '32.',
#   'Title': 'Heat',
#   'Year': '(1995)',
#   'PG': 'R',
#   'Runtime': '170 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '8.3',
#   'Metascore': '76',
#   'Director': ['Michael Mann'],
#   'Stars': ['Al Pacino', 'Robert De Niro', 'Val Kilmer', 'Jon Voight'],
#   'Description': 'A group of high-end professional thieves start to feel the heat from the LAPD when they unknowingly leave a clue at their latest heist.',
#   'Votes': '681,345',
#   'Gross': '$67.44M'},
#  {'Rank': '33.',
#   'Title': 'The Green Mile',
#   'Year': '(1999)',
#   'PG': 'R',
#   'Runtime': '189 min',
#   'Genre': 'Crime, Drama, Fantasy',
#   'IMDB_Rating': '8.6',
#   'Metascore': '61',
#   'Director': ['Frank Darabont'],
#   'Stars': ['Tom Hanks',
#    'Michael Clarke Duncan',
#    'David Morse',
#    'Bonnie Hunt'],
#   'Description': "A tale set on death row in a Southern jail, where gentle giant John possesses the mysterious power to heal people's ailments. When the lead guard, Paul, recognizes John's gift, he tries to help stave off the condemned man's execution.",
#   'Votes': '1,342,705',
#   'Gross': '$136.80M'},
#  {'Rank': '34.',
#   'Title': 'Blade Runner 2049',
#   'Year': '(2017)',
#   'PG': 'R',
#   'Runtime': '164 min',
#   'Genre': 'Action, Drama, Mystery',
#   'IMDB_Rating': '8.0',
#   'Metascore': '81',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Harrison Ford', 'Ryan Gosling', 'Ana de Armas', 'Dave Bautista'],
#   'Description': "Young Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years.",
#   'Votes': '609,366',
#   'Gross': '$92.05M'},
#  {'Rank': '35.',
#   'Title': 'Inglourious Basterds',
#   'Year': '(2009)',
#   'PG': 'R',
#   'Runtime': '153 min',
#   'Genre': 'Adventure, Drama, War',
#   'IMDB_Rating': '8.3',
#   'Metascore': '69',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['Brad Pitt', 'Diane Kruger', 'Eli Roth', 'Mélanie Laurent'],
#   'Description': "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.",
#   'Votes': '1,500,643',
#   'Gross': '$120.54M'},
#  {'Rank': '36.',
#   'Title': 'Little Miss Sunshine',
#   'Year': '(2006)',
#   'PG': 'R',
#   'Runtime': '101 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '80',
#   'Director': ['Jonathan Dayton', 'Valerie Faris'],
#   'Stars': ['Steve Carell',
#    'Toni Collette',
#    'Greg Kinnear',
#    'Abigail Breslin'],
#   'Description': 'A family determined to get their young daughter into the finals of a beauty pageant take a cross-country trip in their VW bus.',
#   'Votes': '498,135',
#   'Gross': '$59.89M'},
#  {'Rank': '37.',
#   'Title': 'Goodfellas',
#   'Year': '(1990)',
#   'PG': 'R',
#   'Runtime': '145 min',
#   'Genre': 'Biography, Crime, Drama',
#   'IMDB_Rating': '8.7',
#   'Metascore': '92',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Robert De Niro', 'Ray Liotta', 'Joe Pesci', 'Lorraine Bracco'],
#   'Description': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.',
#   'Votes': '1,198,618',
#   'Gross': '$46.84M'},
#  {'Rank': '38.',
#   'Title': 'Prisoners',
#   'Year': '(2013)',
#   'PG': 'R',
#   'Runtime': '153 min',
#   'Genre': 'Crime, Drama, Mystery',
#   'IMDB_Rating': '8.1',
#   'Metascore': '70',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis', 'Melissa Leo'],
#   'Description': "When Keller Dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts.",
#   'Votes': '752,979',
#   'Gross': '$61.00M'},
#  {'Rank': '39.',
#   'Title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'Year': '(2001)',
#   'PG': 'PG-13',
#   'Runtime': '178 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.8',
#   'Metascore': '92',
#   'Director': ['Peter Jackson'],
#   'Stars': ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom', 'Sean Bean'],
#   'Description': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.',
#   'Votes': '1,924,179',
#   'Gross': '$315.54M'},
#  {'Rank': '40.',
#   'Title': 'Apocalypse Now',
#   'Year': '(1979)',
#   'PG': 'R',
#   'Runtime': '147 min',
#   'Genre': 'Drama, Mystery, War',
#   'IMDB_Rating': '8.4',
#   'Metascore': '94',
#   'Director': ['Francis Ford Coppola'],
#   'Stars': ['Martin Sheen',
#    'Marlon Brando',
#    'Robert Duvall',
#    'Frederic Forrest'],
#   'Description': 'A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.',
#   'Votes': '684,966',
#   'Gross': '$83.47M'},
#  {'Rank': '41.',
#   'Title': 'Puss in Boots: The Last Wish',
#   'Year': '(2022)',
#   'PG': 'PG',
#   'Runtime': '102 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '73',
#   'Director': ['Joel Crawford', 'Januel Mercado'],
#   'Stars': ['Antonio Banderas',
#    'Salma Hayek',
#    'Harvey Guillén',
#    'Florence Pugh'],
#   'Description': 'When Puss in Boots discovers that his passion for adventure has taken its toll and he has burned through eight of his nine lives, he launches an epic journey to restore them by finding the mythical Last Wish.',
#   'Votes': '138,258',
#   'Gross': '$168.46M'},
#  {'Rank': '42.',
#   'Title': 'Aliens',
#   'Year': '(1986)',
#   'PG': 'R',
#   'Runtime': '137 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.4',
#   'Metascore': '84',
#   'Director': ['James Cameron'],
#   'Stars': ['Sigourney Weaver', 'Michael Biehn', 'Carrie Henn', 'Paul Reiser'],
#   'Description': 'Decades after surviving the Nostromo incident, Ellen Ripley is sent out to re-establish contact with a terraforming colony but finds herself battling the Alien Queen and her offspring.',
#   'Votes': '735,665',
#   'Gross': '$85.16M'},
#  {'Rank': '43.',
#   'Title': 'Jurassic Park',
#   'Year': '(1993)',
#   'PG': 'PG-13',
#   'Runtime': '127 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.2',
#   'Metascore': '68',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Sam Neill',
#    'Laura Dern',
#    'Jeff Goldblum',
#    'Richard Attenborough'],
#   'Description': "A pragmatic paleontologist touring an almost complete theme park on an island in Central America is tasked with protecting a couple of kids after a power failure causes the park's cloned dinosaurs to run loose.",
#   'Votes': '1,020,515',
#   'Gross': '$402.45M'},
#  {'Rank': '44.',
#   'Title': 'American Psycho',
#   'Year': '(2000)',
#   'PG': 'R',
#   'Runtime': '102 min',
#   'Genre': 'Crime, Drama, Horror',
#   'IMDB_Rating': '7.6',
#   'Metascore': '64',
#   'Director': ['Mary Harron'],
#   'Stars': ['Christian Bale', 'Justin Theroux', 'Josh Lucas', 'Bill Sage'],
#   'Description': 'A wealthy New York City investment banking executive, Patrick Bateman, hides his alternate psychopathic ego from his co-workers and friends as he delves deeper into his violent, hedonistic fantasies.',
#   'Votes': '662,016',
#   'Gross': '$15.07M'},
#  {'Rank': '45.',
#   'Title': 'Dunkirk',
#   'Year': '(2017)',
#   'PG': 'PG-13',
#   'Runtime': '106 min',
#   'Genre': 'Action, Drama, History',
#   'IMDB_Rating': '7.8',
#   'Metascore': '94',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Fionn Whitehead', 'Barry Keoghan', 'Mark Rylance', 'Tom Hardy'],
#   'Description': 'Allied soldiers from Belgium, the British Commonwealth and Empire, and France are surrounded by the German Army and evacuated during a fierce battle in World War II.',
#   'Votes': '686,811',
#   'Gross': '$188.37M'},
#  {'Rank': '46.',
#   'Title': 'Back to the Future',
#   'Year': '(1985)',
#   'PG': 'PG',
#   'Runtime': '116 min',
#   'Genre': 'Adventure, Comedy, Sci-Fi',
#   'IMDB_Rating': '8.5',
#   'Metascore': '87',
#   'Director': ['Robert Zemeckis'],
#   'Stars': ['Michael J. Fox',
#    'Christopher Lloyd',
#    'Lea Thompson',
#    'Crispin Glover'],
#   'Description': 'Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.',
#   'Votes': '1,246,408',
#   'Gross': '$210.61M'},
#  {'Rank': '47.',
#   'Title': 'A Bronx Tale',
#   'Year': '(1993)',
#   'PG': 'R',
#   'Runtime': '121 min',
#   'Genre': 'Crime, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '80',
#   'Director': ['Robert De Niro'],
#   'Stars': ['Robert De Niro',
#    'Chazz Palminteri',
#    'Lillo Brancato',
#    'Francis Capra'],
#   'Description': 'A father becomes worried when a local gangster befriends his son in the Bronx in the 1960s.',
#   'Votes': '150,573',
#   'Gross': '$17.27M'},
#  {'Rank': '48.',
#   'Title': 'Terminator 2: Judgment Day',
#   'Year': '(1991)',
#   'PG': 'R',
#   'Runtime': '137 min',
#   'Genre': 'Action, Sci-Fi',
#   'IMDB_Rating': '8.6',
#   'Metascore': '75',
#   'Director': ['James Cameron'],
#   'Stars': ['Arnold Schwarzenegger',
#    'Linda Hamilton',
#    'Edward Furlong',
#    'Robert Patrick'],
#   'Description': 'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten year old son John from an even more advanced and powerful cyborg.',
#   'Votes': '1,128,937',
#   'Gross': '$204.84M'},
#  {'Rank': '49.',
#   'Title': 'Se7en',
#   'Year': '(1995)',
#   'PG': 'R',
#   'Runtime': '127 min',
#   'Genre': 'Crime, Drama, Mystery',
#   'IMDB_Rating': '8.6',
#   'Metascore': '65',
#   'Director': ['David Fincher'],
#   'Stars': ['Morgan Freeman',
#    'Brad Pitt',
#    'Kevin Spacey',
#    'Andrew Kevin Walker'],
#   'Description': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#   'Votes': '1,707,428',
#   'Gross': '$100.13M'},
#  {'Rank': '50.',
#   'Title': 'The Departed',
#   'Year': '(2006)',
#   'PG': 'R',
#   'Runtime': '151 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.5',
#   'Metascore': '85',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Leonardo DiCaprio',
#    'Matt Damon',
#    'Jack Nicholson',
#    'Mark Wahlberg'],
#   'Description': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.',
#   'Votes': '1,363,031',
#   'Gross': '$132.38M'},
#  {'Rank': '51.',
#   'Title': 'Fight Club',
#   'Year': '(1999)',
#   'PG': 'R',
#   'Runtime': '139 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.8',
#   'Metascore': '67',
#   'Director': ['David Fincher'],
#   'Stars': ['Brad Pitt', 'Edward Norton', 'Meat Loaf', 'Zach Grenier'],
#   'Description': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.',
#   'Votes': '2,198,847',
#   'Gross': '$37.03M'},
#  {'Rank': '52.',
#   'Title': 'Gladiator',
#   'Year': '(2000)',
#   'PG': 'R',
#   'Runtime': '155 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.5',
#   'Metascore': '67',
#   'Director': ['Ridley Scott'],
#   'Stars': ['Russell Crowe',
#    'Joaquin Phoenix',
#    'Connie Nielsen',
#    'Oliver Reed'],
#   'Description': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.',
#   'Votes': '1,543,280',
#   'Gross': '$187.71M'},
#  {'Rank': '53.',
#   'Title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Year': '(2003)',
#   'PG': 'PG-13',
#   'Runtime': '143 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '8.1',
#   'Metascore': '63',
#   'Director': ['Gore Verbinski'],
#   'Stars': ['Johnny Depp',
#    'Geoffrey Rush',
#    'Orlando Bloom',
#    'Keira Knightley'],
#   'Description': 'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.',
#   'Votes': '1,159,407',
#   'Gross': '$305.41M'},
#  {'Rank': '54.',
#   'Title': 'Blade Runner',
#   'Year': '(1982)',
#   'PG': 'R',
#   'Runtime': '117 min',
#   'Genre': 'Action, Drama, Sci-Fi',
#   'IMDB_Rating': '8.1',
#   'Metascore': '84',
#   'Director': ['Ridley Scott'],
#   'Stars': ['Harrison Ford',
#    'Rutger Hauer',
#    'Sean Young',
#    'Edward James Olmos'],
#   'Description': 'A blade runner must pursue and terminate four replicants who stole a ship in space and have returned to Earth to find their creator.',
#   'Votes': '791,709',
#   'Gross': '$32.87M'},
#  {'Rank': '55.',
#   'Title': 'The Terminator',
#   'Year': '(1984)',
#   'PG': 'R',
#   'Runtime': '107 min',
#   'Genre': 'Action, Sci-Fi',
#   'IMDB_Rating': '8.1',
#   'Metascore': '84',
#   'Director': ['James Cameron'],
#   'Stars': ['Arnold Schwarzenegger',
#    'Linda Hamilton',
#    'Michael Biehn',
#    'Paul Winfield'],
#   'Description': "A human soldier is sent from 2029 to 1984 to stop an almost indestructible cyborg killing machine, sent from the same year, which has been programmed to execute a young woman whose unborn son is the key to humanity's future salvation.",
#   'Votes': '890,190',
#   'Gross': '$38.40M'},
#  {'Rank': '56.',
#   'Title': "Zack Snyder's Justice League",
#   'Year': '(2021)',
#   'PG': 'R',
#   'Runtime': '242 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '54',
#   'Director': ['Zack Snyder'],
#   'Stars': ['Henry Cavill', 'Ben Affleck', 'Gal Gadot', 'Amy Adams'],
#   'Description': "Determined to ensure that Superman's ultimate sacrifice wasn't in vain, Bruce Wayne recruits a team of metahumans to protect the world from an approaching threat of catastrophic proportions.",
#   'Votes': '416,925',
#   'Gross': 0},
#  {'Rank': '57.',
#   'Title': 'Joker',
#   'Year': '(I) (2019)',
#   'PG': 'R',
#   'Runtime': '122 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.4',
#   'Metascore': '59',
#   'Director': ['Todd Phillips'],
#   'Stars': ['Joaquin Phoenix',
#    'Robert De Niro',
#    'Zazie Beetz',
#    'Frances Conroy'],
#   'Description': "The rise of Arthur Fleck, from aspiring stand-up comedian and pariah to Gotham's clown prince and leader of the revolution.",
#   'Votes': '1,367,042',
#   'Gross': '$335.45M'},
#  {'Rank': '58.',
#   'Title': 'Saving Private Ryan',
#   'Year': '(1998)',
#   'PG': 'R',
#   'Runtime': '169 min',
#   'Genre': 'Drama, War',
#   'IMDB_Rating': '8.6',
#   'Metascore': '91',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Tom Hanks', 'Matt Damon', 'Tom Sizemore', 'Edward Burns'],
#   'Description': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.',
#   'Votes': '1,430,509',
#   'Gross': '$216.54M'},
#  {'Rank': '59.',
#   'Title': 'The Matrix',
#   'Year': '(1999)',
#   'PG': 'R',
#   'Runtime': '136 min',
#   'Genre': 'Action, Sci-Fi',
#   'IMDB_Rating': '8.7',
#   'Metascore': '73',
#   'Director': ['Lana Wachowski', 'Lilly Wachowski'],
#   'Stars': ['Keanu Reeves',
#    'Laurence Fishburne',
#    'Carrie-Anne Moss',
#    'Hugo Weaving'],
#   'Description': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.',
#   'Votes': '1,967,595',
#   'Gross': '$171.48M'},
#  {'Rank': '60.',
#   'Title': 'Forrest Gump',
#   'Year': '(1994)',
#   'PG': 'PG-13',
#   'Runtime': '142 min',
#   'Genre': 'Drama, Romance',
#   'IMDB_Rating': '8.8',
#   'Metascore': '82',
#   'Director': ['Robert Zemeckis'],
#   'Stars': ['Tom Hanks', 'Robin Wright', 'Gary Sinise', 'Sally Field'],
#   'Description': "The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.",
#   'Votes': '2,147,986',
#   'Gross': '$330.25M'},
#  {'Rank': '61.',
#   'Title': 'Moonrise Kingdom',
#   'Year': '(2012)',
#   'PG': 'PG-13',
#   'Runtime': '94 min',
#   'Genre': 'Comedy, Drama, Family',
#   'IMDB_Rating': '7.8',
#   'Metascore': '84',
#   'Director': ['Wes Anderson'],
#   'Stars': ['Jared Gilman', 'Kara Hayward', 'Bruce Willis', 'Bill Murray'],
#   'Description': 'A pair of young lovers flee their New England town, which causes a local search party to fan out to find them.',
#   'Votes': '358,866',
#   'Gross': '$45.51M'},
#  {'Rank': '62.',
#   'Title': 'Guardians of the Galaxy',
#   'Year': '(2014)',
#   'PG': 'PG-13',
#   'Runtime': '121 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '8.0',
#   'Metascore': '76',
#   'Director': ['James Gunn'],
#   'Stars': ['Chris Pratt', 'Vin Diesel', 'Bradley Cooper', 'Zoe Saldana'],
#   'Description': 'A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.',
#   'Votes': '1,226,843',
#   'Gross': '$333.18M'},
#  {'Rank': '63.',
#   'Title': 'Alien',
#   'Year': '(1979)',
#   'PG': 'R',
#   'Runtime': '117 min',
#   'Genre': 'Horror, Sci-Fi',
#   'IMDB_Rating': '8.5',
#   'Metascore': '89',
#   'Director': ['Ridley Scott'],
#   'Stars': ['Sigourney Weaver',
#    'Tom Skerritt',
#    'John Hurt',
#    'Veronica Cartwright'],
#   'Description': 'The crew of a commercial spacecraft encounter a deadly lifeform after investigating an unknown transmission.',
#   'Votes': '907,857',
#   'Gross': '$78.90M'},
#  {'Rank': '64.',
#   'Title': 'Shutter Island',
#   'Year': '(2010)',
#   'PG': 'R',
#   'Runtime': '138 min',
#   'Genre': 'Mystery, Thriller',
#   'IMDB_Rating': '8.2',
#   'Metascore': '63',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Leonardo DiCaprio',
#    'Emily Mortimer',
#    'Mark Ruffalo',
#    'Ben Kingsley'],
#   'Description': 'Teddy Daniels and Chuck Aule, two US marshals, are sent to an asylum on a remote island in order to investigate the disappearance of a patient, where Teddy uncovers a shocking truth about the place.',
#   'Votes': '1,370,138',
#   'Gross': '$128.01M'},
#  {'Rank': '65.',
#   'Title': 'Parasite',
#   'Year': '(2019)',
#   'PG': 'R',
#   'Runtime': '132 min',
#   'Genre': 'Drama, Thriller',
#   'IMDB_Rating': '8.5',
#   'Metascore': '96',
#   'Director': ['Bong Joon Ho'],
#   'Stars': ['Song Kang-ho', 'Lee Sun-kyun', 'Cho Yeo-jeong', 'Choi Woo-sik'],
#   'Description': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.',
#   'Votes': '864,187',
#   'Gross': '$53.37M'},
#  {'Rank': '66.',
#   'Title': 'The Silence of the Lambs',
#   'Year': '(1991)',
#   'PG': 'R',
#   'Runtime': '118 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.6',
#   'Metascore': '86',
#   'Director': ['Jonathan Demme'],
#   'Stars': ['Jodie Foster',
#    'Anthony Hopkins',
#    'Lawrence A. Bonney',
#    'Kasi Lemmons'],
#   'Description': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.',
#   'Votes': '1,474,805',
#   'Gross': '$130.74M'},
#  {'Rank': '67.',
#   'Title': 'The Breakfast Club',
#   'Year': '(1985)',
#   'PG': 'R',
#   'Runtime': '97 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '66',
#   'Director': ['John Hughes'],
#   'Stars': ['Emilio Estevez', 'Judd Nelson', 'Molly Ringwald', 'Ally Sheedy'],
#   'Description': 'Five high school students meet in Saturday detention and discover how they have a great deal more in common than they thought.',
#   'Votes': '417,371',
#   'Gross': '$45.88M'},
#  {'Rank': '68.',
#   'Title': "Schindler's List",
#   'Year': '(1993)',
#   'PG': 'R',
#   'Runtime': '195 min',
#   'Genre': 'Biography, Drama, History',
#   'IMDB_Rating': '9.0',
#   'Metascore': '95',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Liam Neeson',
#    'Ralph Fiennes',
#    'Ben Kingsley',
#    'Caroline Goodall'],
#   'Description': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.',
#   'Votes': '1,391,455',
#   'Gross': '$96.90M'},
#  {'Rank': '69.',
#   'Title': 'The Prestige',
#   'Year': '(2006)',
#   'PG': 'PG-13',
#   'Runtime': '130 min',
#   'Genre': 'Drama, Mystery, Sci-Fi',
#   'IMDB_Rating': '8.5',
#   'Metascore': '66',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Christian Bale',
#    'Hugh Jackman',
#    'Scarlett Johansson',
#    'Michael Caine'],
#   'Description': 'After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.',
#   'Votes': '1,371,346',
#   'Gross': '$53.09M'},
#  {'Rank': '70.',
#   'Title': 'The Banshees of Inisherin',
#   'Year': '(2022)',
#   'PG': 'R',
#   'Runtime': '114 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '87',
#   'Director': ['Martin McDonagh'],
#   'Stars': ['Colin Farrell', 'Brendan Gleeson', 'Kerry Condon', 'Pat Shortt'],
#   'Description': 'Two lifelong friends find themselves at an impasse when one abruptly ends their relationship, with alarming consequences for both of them.',
#   'Votes': '215,130',
#   'Gross': 0},
#  {'Rank': '71.',
#   'Title': 'The Goonies',
#   'Year': '(1985)',
#   'PG': 'PG',
#   'Runtime': '114 min',
#   'Genre': 'Adventure, Comedy, Family',
#   'IMDB_Rating': '7.7',
#   'Metascore': '62',
#   'Director': ['Richard Donner'],
#   'Stars': ['Sean Astin', 'Josh Brolin', 'Jeff Cohen', 'Corey Feldman'],
#   'Description': "A group of young misfits called The Goonies discover an ancient map and set out on an adventure to find a legendary pirate's long-lost treasure.",
#   'Votes': '286,407',
#   'Gross': '$61.50M'},
#  {'Rank': '72.',
#   'Title': 'The Gentlemen',
#   'Year': '(2019)',
#   'PG': 'R',
#   'Runtime': '113 min',
#   'Genre': 'Action, Comedy, Crime',
#   'IMDB_Rating': '7.8',
#   'Metascore': '51',
#   'Director': ['Guy Ritchie'],
#   'Stars': ['Matthew McConaughey',
#    'Charlie Hunnam',
#    'Michelle Dockery',
#    'Jeremy Strong'],
#   'Description': 'An American expat tries to sell off his highly profitable marijuana empire in London, triggering plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.',
#   'Votes': '363,708',
#   'Gross': '$36.47M'},
#  {'Rank': '73.',
#   'Title': 'Whiplash',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '106 min',
#   'Genre': 'Drama, Music',
#   'IMDB_Rating': '8.5',
#   'Metascore': '89',
#   'Director': ['Damien Chazelle'],
#   'Stars': ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist', 'Paul Reiser'],
#   'Description': "A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#   'Votes': '912,552',
#   'Gross': '$13.09M'},
#  {'Rank': '74.',
#   'Title': 'The Dark Knight Rises',
#   'Year': '(2012)',
#   'PG': 'PG-13',
#   'Runtime': '164 min',
#   'Genre': 'Action, Drama, Thriller',
#   'IMDB_Rating': '8.4',
#   'Metascore': '78',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman'],
#   'Description': "Eight years after the Joker's reign of chaos, Batman is coerced out of exile with the assistance of the mysterious Selina Kyle in order to defend Gotham City from the vicious guerrilla terrorist Bane.",
#   'Votes': '1,750,551',
#   'Gross': '$448.14M'},
#  {'Rank': '75.',
#   'Title': 'Aftersun',
#   'Year': '(II) (2022)',
#   'PG': 'R',
#   'Runtime': '102 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '95',
#   'Director': ['Charlotte Wells'],
#   'Stars': ['Paul Mescal',
#    'Frankie Corio',
#    'Celia Rowlson-Hall',
#    'Sally Messham'],
#   'Description': "Sophie reflects on the shared joy and private melancholy of a holiday she took with her father twenty years earlier. Memories real and imagined fill the gaps between as she tries to reconcile the father she knew with the man she didn't...",
#   'Votes': '67,019',
#   'Gross': 0},
#  {'Rank': '76.',
#   'Title': 'Avengers: Infinity War',
#   'Year': '(2018)',
#   'PG': 'PG-13',
#   'Runtime': '149 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.4',
#   'Metascore': '68',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Stars': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans'],
#   'Description': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.',
#   'Votes': '1,133,431',
#   'Gross': '$678.82M'},
#  {'Rank': '77.',
#   'Title': 'Get Out',
#   'Year': '(I) (2017)',
#   'PG': 'R',
#   'Runtime': '104 min',
#   'Genre': 'Horror, Mystery, Thriller',
#   'IMDB_Rating': '7.8',
#   'Metascore': '85',
#   'Director': ['Jordan Peele'],
#   'Stars': ['Daniel Kaluuya',
#    'Allison Williams',
#    'Bradley Whitford',
#    'Catherine Keener'],
#   'Description': "A young African-American visits his White girlfriend's parents for the weekend, where his simmering uneasiness about their reception of him eventually reaches a boiling point.",
#   'Votes': '645,268',
#   'Gross': '$176.04M'},
#  {'Rank': '78.',
#   'Title': 'Kingsman: The Secret Service',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '129 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '7.7',
#   'Metascore': '60',
#   'Director': ['Matthew Vaughn'],
#   'Stars': ['Colin Firth',
#    'Taron Egerton',
#    'Samuel L. Jackson',
#    'Michael Caine'],
#   'Description': "A spy organisation recruits a promising street kid into the agency's training program, while a global threat emerges from a twisted tech genius.",
#   'Votes': '690,134',
#   'Gross': '$128.26M'},
#  {'Rank': '79.',
#   'Title': 'The Fifth Element',
#   'Year': '(1997)',
#   'PG': 'PG-13',
#   'Runtime': '126 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '7.6',
#   'Metascore': '52',
#   'Director': ['Luc Besson'],
#   'Stars': ['Bruce Willis', 'Milla Jovovich', 'Gary Oldman', 'Ian Holm'],
#   'Description': 'In the colorful future, a cab driver unwittingly becomes the central figure in the search for a legendary cosmic weapon to keep Evil and Mr. Zorg at bay.',
#   'Votes': '487,977',
#   'Gross': '$63.54M'},
#  {'Rank': '80.',
#   'Title': 'Arrival',
#   'Year': '(II) (2016)',
#   'PG': 'PG-13',
#   'Runtime': '116 min',
#   'Genre': 'Drama, Mystery, Sci-Fi',
#   'IMDB_Rating': '7.9',
#   'Metascore': '81',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Amy Adams',
#    'Jeremy Renner',
#    'Forest Whitaker',
#    'Michael Stuhlbarg'],
#   'Description': 'A linguist works with the military to communicate with alien lifeforms after twelve mysterious spacecraft appear around the world.',
#   'Votes': '723,892',
#   'Gross': '$100.55M'},
#  {'Rank': '81.',
#   'Title': 'Léon: The Professional',
#   'Year': '(1994)',
#   'PG': 'R',
#   'Runtime': '110 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '8.5',
#   'Metascore': '64',
#   'Director': ['Luc Besson'],
#   'Stars': ['Jean Reno', 'Gary Oldman', 'Natalie Portman', 'Danny Aiello'],
#   'Description': "12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.",
#   'Votes': '1,195,152',
#   'Gross': '$19.50M'},
#  {'Rank': '82.',
#   'Title': 'Fantastic Mr. Fox',
#   'Year': '(2009)',
#   'PG': 'PG',
#   'Runtime': '87 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '83',
#   'Director': ['Wes Anderson'],
#   'Stars': ['George Clooney',
#    'Meryl Streep',
#    'Bill Murray',
#    'Jason Schwartzman'],
#   'Description': "An urbane fox cannot resist returning to his farm raiding ways and then must help his community survive the farmers' retaliation.",
#   'Votes': '249,836',
#   'Gross': '$21.00M'},
#  {'Rank': '83.',
#   'Title': 'Deadpool',
#   'Year': '(2016)',
#   'PG': 'R',
#   'Runtime': '108 min',
#   'Genre': 'Action, Comedy',
#   'IMDB_Rating': '8.0',
#   'Metascore': '65',
#   'Director': ['Tim Miller'],
#   'Stars': ['Ryan Reynolds', 'Morena Baccarin', 'T.J. Miller', 'Ed Skrein'],
#   'Description': 'A wisecracking mercenary gets experimented on and becomes immortal but ugly, and sets out to track down the man who ruined his looks.',
#   'Votes': '1,073,858',
#   'Gross': '$363.07M'},
#  {'Rank': '84.',
#   'Title': 'Mad Max: Fury Road',
#   'Year': '(2015)',
#   'PG': 'R',
#   'Runtime': '120 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.1',
#   'Metascore': '90',
#   'Director': ['George Miller'],
#   'Stars': ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult', 'Zoë Kravitz'],
#   'Description': 'In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper and a drifter named Max.',
#   'Votes': '1,035,264',
#   'Gross': '$154.06M'},
#  {'Rank': '85.',
#   'Title': 'The Shining',
#   'Year': '(1980)',
#   'PG': 'R',
#   'Runtime': '146 min',
#   'Genre': 'Drama, Horror',
#   'IMDB_Rating': '8.4',
#   'Metascore': '66',
#   'Director': ['Stanley Kubrick'],
#   'Stars': ['Jack Nicholson',
#    'Shelley Duvall',
#    'Danny Lloyd',
#    'Scatman Crothers'],
#   'Description': 'A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.',
#   'Votes': '1,054,826',
#   'Gross': '$44.02M'},
#  {'Rank': '86.',
#   'Title': 'Gone Girl',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '149 min',
#   'Genre': 'Drama, Mystery, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '79',
#   'Director': ['David Fincher'],
#   'Stars': ['Ben Affleck',
#    'Rosamund Pike',
#    'Neil Patrick Harris',
#    'Tyler Perry'],
#   'Description': "With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.",
#   'Votes': '1,013,647',
#   'Gross': '$167.77M'},
#  {'Rank': '87.',
#   'Title': 'Full Metal Jacket',
#   'Year': '(1987)',
#   'PG': 'R',
#   'Runtime': '116 min',
#   'Genre': 'Drama, War',
#   'IMDB_Rating': '8.3',
#   'Metascore': '78',
#   'Director': ['Stanley Kubrick'],
#   'Stars': ['Matthew Modine',
#    'R. Lee Ermey',
#    "Vincent D'Onofrio",
#    'Adam Baldwin'],
#   'Description': 'A pragmatic U.S. Marine observes the dehumanizing effects the Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.',
#   'Votes': '762,076',
#   'Gross': '$46.36M'},
#  {'Rank': '88.',
#   'Title': 'No Country for Old Men',
#   'Year': '(2007)',
#   'PG': 'R',
#   'Runtime': '122 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.2',
#   'Metascore': '92',
#   'Director': ['Ethan Coen', 'Joel Coen'],
#   'Stars': ['Tommy Lee Jones',
#    'Javier Bardem',
#    'Josh Brolin',
#    'Woody Harrelson'],
#   'Description': 'Violence and mayhem ensue after a hunter stumbles upon a drug deal gone wrong and more than two million dollars in cash near the Rio Grande.',
#   'Votes': '1,006,987',
#   'Gross': '$74.28M'},
#  {'Rank': '89.',
#   'Title': 'Rain Man',
#   'Year': '(1988)',
#   'PG': 'R',
#   'Runtime': '133 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '65',
#   'Director': ['Barry Levinson'],
#   'Stars': ['Dustin Hoffman',
#    'Tom Cruise',
#    'Valeria Golino',
#    'Gerald R. Molen'],
# ...
#    'Trisha Krishnan',
#    'Gouri Kishan'],
#   'Description': 'Two high school sweethearts meet at a reunion after 22 years and reminisce about their past.',
#   'Votes': '33,416',
#   'Gross': 0},
#  {'Rank': '969.',
#   'Title': 'Tae Guk Gi: The Brotherhood of War',
#   'Year': '(2004)',
#   'PG': 'R',
#   'Runtime': '140 min',
#   'Genre': 'Action, Drama, War',
#   'IMDB_Rating': '8.0',
#   'Metascore': '64',
#   'Director': ['Je-kyu Kang'],
#   'Stars': ['Jang Dong-Gun', 'Won Bin', 'Eun-ju Lee', 'Hyeong-jin Kong'],
#   'Description': 'When two brothers are forced to fight in the Korean War, the elder decides to take the riskiest missions if it will help shield the younger from battle.',
#   'Votes': '40,430',
#   'Gross': '$1.11M'},
#  {'Rank': '970.',
#   'Title': 'Tangerines',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '87 min',
#   'Genre': 'Drama, War',
#   'IMDB_Rating': '8.1',
#   'Metascore': '73',
#   'Director': ['Zaza Urushadze'],
#   'Stars': ['Lembit Ulfsak',
#    'Elmo Nüganen',
#    'Giorgi Nakashidze',
#    'Misha Meskhi'],
#   'Description': 'In 1992, war rages in Abkhazia, a breakaway region of Georgia. An Estonian man Ivo has decided to stay behind and harvest his crops of tangerines. In a bloody conflict at his door, a wounded man is left behind, and Ivo takes him in.',
#   'Votes': '47,668',
#   'Gross': '$0.14M'},
#  {'Rank': '971.',
#   'Title': 'A Night at the Opera',
#   'Year': '(1935)',
#   'PG': 'Passed',
#   'Runtime': '96 min',
#   'Genre': 'Comedy, Music, Musical',
#   'IMDB_Rating': '7.8',
#   'Metascore': '0',
#   'Director': ['Sam Wood', 'Edmund Goulding'],
#   'Stars': ['Groucho Marx', 'Chico Marx', 'Harpo Marx', 'Kitty Carlisle'],
#   'Description': 'A sly business manager and the wacky friends of two opera singers in Italy help them achieve success in America while humiliating their stuffy and snobbish enemies.',
#   'Votes': '33,833',
#   'Gross': '$2.54M'},
#  {'Rank': '972.',
#   'Title': 'Winter Light',
#   'Year': '(1963)',
#   'PG': 'Not Rated',
#   'Runtime': '81 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Ingmar Bergman'],
#   'Stars': ['Ingrid Thulin',
#    'Gunnar Björnstrand',
#    'Gunnel Lindblom',
#    'Max von Sydow'],
#   'Description': 'A small-town priest struggles with his faith.',
#   'Votes': '26,080',
#   'Gross': 0},
#  {'Rank': '973.',
#   'Title': 'Zelig',
#   'Year': '(1983)',
#   'PG': 'PG',
#   'Runtime': '79 min',
#   'Genre': 'Comedy',
#   'IMDB_Rating': '7.7',
#   'Metascore': '0',
#   'Director': ['Woody Allen'],
#   'Stars': ['Woody Allen', 'Mia Farrow', 'Patrick Horgan', 'John Buckwalter'],
#   'Description': '"Documentary" about a man who can look and act like whoever he\'s around, and meets various famous people.',
#   'Votes': '43,140',
#   'Gross': '$11.80M'},
#  {'Rank': '974.',
#   'Title': 'Paan Singh Tomar',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '135 min',
#   'Genre': 'Action, Biography, Crime',
#   'IMDB_Rating': '8.2',
#   'Metascore': '0',
#   'Director': ['Tigmanshu Dhulia'],
#   'Stars': ['Irrfan Khan', 'Mahie Gill', 'Rajesh Abhay', 'Hemendra Dandotiya'],
#   'Description': 'The story of Paan Singh Tomar, an Indian athlete and seven-time national steeplechase champion who becomes one of the most feared dacoits in Chambal Valley after his retirement.',
#   'Votes': '37,140',
#   'Gross': '$0.04M'},
#  {'Rank': '975.',
#   'Title': 'Rangasthalam 1985',
#   'Year': '(2018)',
#   'PG': 'Not Rated',
#   'Runtime': '170 min',
#   'Genre': 'Action, Drama',
#   'IMDB_Rating': '8.2',
#   'Metascore': '0',
#   'Director': ['Sukumar'],
#   'Stars': ['Ram Charan', 'Samantha Ruth Prabhu', 'Aadhi', 'Jagapathi Babu'],
#   'Description': "Chitti Babu begins to suspect his elder brother's life is in danger after they team up to lock horns with their village president and overthrow his unlawful 30 year old regime.",
#   'Votes': '26,293',
#   'Gross': '$3.51M'},
#  {'Rank': '976.',
#   'Title': 'Asuran',
#   'Year': '(2019)',
#   'PG': 'Not Rated',
#   'Runtime': '141 min',
#   'Genre': 'Action, Drama',
#   'IMDB_Rating': '8.4',
#   'Metascore': '0',
#   'Director': ['Vetrimaaran'],
#   'Stars': ['Dhanush', 'Manju Warrier', 'Prakash Raj', 'Pasupathy'],
#   'Description': 'The teenage son of a farmer from an underprivileged caste kills a rich, upper caste landlord. How the pacifist farmer saves his hot-blooded son is the rest of the story.',
#   'Votes': '31,441',
#   'Gross': 0},
#  {'Rank': '977.',
#   'Title': 'Carry On, Munna Bhai',
#   'Year': '(2006)',
#   'PG': 'Not Rated',
#   'Runtime': '144 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Rajkumar Hirani'],
#   'Stars': ['Sanjay Dutt', 'Arshad Warsi', 'Vidya Balan', 'Boman Irani'],
#   'Description': 'Munna Bhai embarks on a journey with Mahatma Gandhi in order to fight against a corrupt property dealer.',
#   'Votes': '48,288',
#   'Gross': '$2.22M'},
#  {'Rank': '978.',
#   'Title': 'The Edge of Heaven',
#   'Year': '(2007)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '85',
#   'Director': ['Fatih Akin'],
#   'Stars': ['Baki Davrak', 'Gürsoy Gemec', 'Cengiz Daner', 'Tuncel Kurtiz'],
#   'Description': "A Turkish man travels to Istanbul to find the daughter of his father's former girlfriend.",
#   'Votes': '32,821',
#   'Gross': '$0.74M'},
#  {'Rank': '979.',
#   'Title': 'Kahaani',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Mystery, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Sujoy Ghosh'],
#   'Stars': ['Vidya Balan',
#    'Parambrata Chattopadhyay',
#    'Indraneil Sengupta',
#    'Nawazuddin Siddiqui'],
#   'Description': "A pregnant woman's search for her missing husband takes her from London to Kolkata, but everyone she questions denies having ever met him.",
#   'Votes': '64,190',
#   'Gross': '$1.04M'},
#  {'Rank': '980.',
#   'Title': 'Drishyam',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '160 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.3',
#   'Metascore': '0',
#   'Director': ['Jeethu Joseph'],
#   'Stars': ['Mohanlal', 'Meena', 'Asha Sharath', 'Ansiba'],
#   'Description': 'A man goes to extreme lengths to save his family from punishment after the family commits an accidental crime.',
#   'Votes': '42,776',
#   'Gross': 0},
#  {'Rank': '981.',
#   'Title': 'Hindi Medium',
#   'Year': '(2017)',
#   'PG': 'Not Rated',
#   'Runtime': '132 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '0',
#   'Director': ['Saket Chaudhary'],
#   'Stars': ['Irrfan Khan', 'Saba Qamar', 'Dishita Sehgal', 'Deepak Dobriyal'],
#   'Description': 'A couple from Chandni Chowk aspire to give their daughter the best education and thus be a part of and accepted by the elite of Delhi.',
#   'Votes': '30,736',
#   'Gross': 0},
#  {'Rank': '982.',
#   'Title': 'Hera Pheri',
#   'Year': '(2000)',
#   'PG': 'Not Rated',
#   'Runtime': '156 min',
#   'Genre': 'Action, Comedy, Crime',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Priyadarshan'],
#   'Stars': ['Akshay Kumar', 'Suniel Shetty', 'Paresh Rawal', 'Tabu'],
#   'Description': 'Three unemployed men look for answers to all their money problems - but when their opportunity arrives, will they know what to do with it?',
#   'Votes': '69,721',
#   'Gross': 0},
#  {'Rank': '983.',
#   'Title': 'The Bandit',
#   'Year': '(1996)',
#   'PG': 'Not Rated',
#   'Runtime': '128 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Yavuz Turgul'],
#   'Stars': ['Sener Sen', 'Ugur Yücel', 'Sermin Hürmeriç', 'Yesim Salkim'],
#   'Description': 'Baran the Bandit, released from prison after 35 years, searches for vengeance and his lover.',
#   'Votes': '71,008',
#   'Gross': 0},
#  {'Rank': '984.',
#   'Title': 'The Circus',
#   'Year': '(1928)',
#   'PG': 'Passed',
#   'Runtime': '72 min',
#   'Genre': 'Comedy, Family, Romance',
#   'IMDB_Rating': '8.1',
#   'Metascore': '90',
#   'Director': ['Charles Chaplin'],
#   'Stars': ['Charles Chaplin',
#    'Merna Kennedy',
#    'Al Ernest Garcia',
#    'Harry Crocker'],
#   'Description': 'The Tramp finds work and the girl of his dreams at a circus.',
#   'Votes': '34,981',
#   'Gross': 0},
#  {'Rank': '985.',
#   'Title': 'Bhaag Milkha Bhaag',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '186 min',
#   'Genre': 'Biography, Drama, Sport',
#   'IMDB_Rating': '8.2',
#   'Metascore': '0',
#   'Director': ['Rakeysh Omprakash Mehra'],
#   'Stars': ['Farhan Akhtar', 'Japtej Singh', 'Divya Dutta', 'Pawan Malhotra'],
#   'Description': 'The truth behind the ascension of Milkha Singh, who was scarred by of the India-Pakistan partition.',
#   'Votes': '70,028',
#   'Gross': '$1.63M'},
#  {'Rank': '986.',
#   'Title': 'Udaan',
#   'Year': '(2010)',
#   'PG': 'Not Rated',
#   'Runtime': '134 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Vikramaditya Motwane'],
#   'Stars': ['Rajat Barmecha', 'Ronit Roy', 'Manjot Singh', 'Ram Kapoor'],
#   'Description': 'Expelled from his school, a 16-year old boy returns home to his abusive and oppressive father.',
#   'Votes': '45,993',
#   'Gross': '$0.01M'},
#  {'Rank': '987.',
#   'Title': 'OMG: Oh My God!',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '125 min',
#   'Genre': 'Comedy, Drama, Fantasy',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Umesh Shukla'],
#   'Stars': ['Paresh Rawal',
#    'Akshay Kumar',
#    'Mithun Chakraborty',
#    'Mahesh Manjrekar'],
#   'Description': 'A shopkeeper takes God to court when his shop is destroyed by an earthquake.',
#   'Votes': '60,962',
#   'Gross': '$0.92M'},
#  {'Rank': '988.',
#   'Title': 'Black',
#   'Year': '(2005)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Sanjay Leela Bhansali'],
#   'Stars': ['Amitabh Bachchan',
#    'Rani Mukerji',
#    'Shernaz Patel',
#    'Ayesha Kapur'],
#   'Description': "The cathartic tale of a young woman who can't see, hear, or speak, and the teacher who brings a ray of light into her dark world.",
#   'Votes': '35,530',
#   'Gross': '$0.73M'},
#  {'Rank': '989.',
#   'Title': 'Drishyam 2',
#   'Year': '(2021)',
#   'PG': 'Not Rated',
#   'Runtime': '152 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.4',
#   'Metascore': '0',
#   'Director': ['Jeethu Joseph'],
#   'Stars': ['Mohanlal', 'Meena', 'Ansiba', 'Esther Anil'],
#   'Description': 'A gripping tale of an investigation and a family which is threatened by it. Will Georgekutty be able to protect his family this time?',
#   'Votes': '39,211',
#   'Gross': 0},
#  {'Rank': '990.',
#   'Title': "Everything's Gonna Be Great",
#   'Year': '(1998)',
#   'PG': 'Not Rated',
#   'Runtime': '107 min',
#   'Genre': 'Comedy, Drama, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Ömer Vargi'],
#   'Stars': ['Cem Yilmaz', 'Mazhar Alanson', 'Ceyda Düvenci', 'Selim Nasit'],
#   'Description': "When Altan swipes prescription drugs from his brother Nuri's pharmacy, they soon find themselves on a dangerous but funny road trip to get rid of the stuff and escape the mafiosi Altan ...                See full summary\xa0»",
#   'Votes': '26,403',
#   'Gross': 0},
#  {'Rank': '991.',
#   'Title': 'Special 26',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '144 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Neeraj Pandey'],
#   'Stars': ['Akshay Kumar', 'Anupam Kher', 'Manoj Bajpayee', 'Jimmy Shergill'],
#   'Description': 'A gang of con-men rob prominent rich businessmen and politicians by posing as C.B.I and income tax officers.',
#   'Votes': '57,636',
#   'Gross': '$1.08M'},
#  {'Rank': '992.',
#   'Title': 'The Breath',
#   'Year': '(2009)',
#   'PG': 'Not Rated',
#   'Runtime': '128 min',
#   'Genre': 'Action, Drama, Thriller',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Levent Semerci'],
#   'Stars': ['Mete Horozoglu', 'Ilker Kizmaz', 'Birce Akalay', 'Ibrahim Akoz'],
#   'Description': 'Story of 40-man Turkish task force who must defend a relay station.',
#   'Votes': '34,480',
#   'Gross': 0},
#  {'Rank': '993.',
#   'Title': 'Andaz Apna Apna',
#   'Year': '(1994)',
#   'PG': 'Not Rated',
#   'Runtime': '160 min',
#   'Genre': 'Action, Comedy, Romance',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Rajkumar Santoshi'],
#   'Stars': ['Aamir Khan', 'Salman Khan', 'Raveena Tandon', 'Karisma Kapoor'],
#   'Description': 'Two slackers competing for the affections of an heiress inadvertently become her protectors from an evil criminal.',
#   'Votes': '54,305',
#   'Gross': 0},
#  {'Rank': '994.',
#   'Title': 'Pad Man',
#   'Year': '(2018)',
#   'PG': 'PG-13',
#   'Runtime': '140 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.9',
#   'Metascore': '0',
#   'Director': ['R. Balki'],
#   'Stars': ['Akshay Kumar', 'Radhika Apte', 'Sonam Kapoor', 'Jyoti Subhash'],
#   'Description': 'Upon realizing the extent to which women are affected by their menses, a man sets out to create a sanitary pad machine and to provide inexpensive sanitary pads to the women of rural India.',
#   'Votes': '27,388',
#   'Gross': '$1.66M'},
#  {'Rank': '995.',
#   'Title': 'Baby',
#   'Year': '(I) (2015)',
#   'PG': 'Not Rated',
#   'Runtime': '159 min',
#   'Genre': 'Action, Crime, Thriller',
#   'IMDB_Rating': '7.9',
#   'Metascore': '0',
#   'Director': ['Neeraj Pandey'],
#   'Stars': ['Akshay Kumar',
#    'Danny Denzongpa',
#    'Rana Daggubati',
#    'Taapsee Pannu'],
#   'Description': "An elite counter-intelligence unit learns of a plot, masterminded by a maniacal madman. With the clock ticking, it's up to them to track the terrorists' international tentacles and prevent them from striking at the heart of India.",
#   'Votes': '58,936',
#   'Gross': 0},
#  {'Rank': '996.',
#   'Title': 'Vicky Donor',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '126 min',
#   'Genre': 'Comedy, Romance',
#   'IMDB_Rating': '7.8',
#   'Metascore': '0',
#   'Director': ['Shoojit Sircar'],
#   'Stars': ['Ayushmann Khurrana',
#    'Yami Gautam',
#    'Annu Kapoor',
#    'Dolly Ahluwalia'],
#   'Description': 'A man is brought in by an infertility doctor to supply him with his sperm, where he becomes the biggest sperm donor for his clinic.',
#   'Votes': '44,440',
#   'Gross': '$0.17M'},
#  {'Rank': '997.',
#   'Title': 'Vizontele',
#   'Year': '(2001)',
#   'PG': 'Not Rated',
#   'Runtime': '110 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Yilmaz Erdogan', 'Ömer Faruk Sorak'],
#   'Stars': ['Yilmaz Erdogan', 'Demet Akbag', 'Altan Erkekli', 'Cem Yilmaz'],
#   'Description': 'Lives of residents in a small, Anatolian village change when television is introduced to them.',
#   'Votes': '37,770',
#   'Gross': 0},
#  {'Rank': '998.',
#   'Title': 'Sarfarosh',
#   'Year': '(1999)',
#   'PG': 'Not Rated',
#   'Runtime': '174 min',
#   'Genre': 'Action, Drama, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['John Mathew Matthan'],
#   'Stars': ['Ali Khan',
#    'Akhilendra Mishra',
#    'Makrand Deshpande',
#    'Rajesh Joshi'],
#   'Description': 'After his brother is killed and father severely injured by terrorists, a young med student quits his studies to join the Indian Police Service to wipe out the terrorists.',
#   'Votes': '26,295',
#   'Gross': 0},
#  {'Rank': '999.',
#   'Title': 'Airlift',
#   'Year': '(2016)',
#   'PG': 'Not Rated',
#   'Runtime': '130 min',
#   'Genre': 'Action, Drama, History',
#   'IMDB_Rating': '7.9',
#   'Metascore': '0',
#   'Director': ['Raja Menon'],
#   'Stars': ['Akshay Kumar', 'Nimrat Kaur', 'Kumud Mishra', 'Prakash Belawadi'],
#   'Description': 'When Iraq invades Kuwait in August 1990, a callous Indian businessman becomes the spokesperson for more than 170,000 stranded countrymen.',
#   'Votes': '57,938',
#   'Gross': 0},
#  {'Rank': '1,000.',
#   'Title': 'Anand',
#   'Year': '(1971)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Drama, Musical',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Hrishikesh Mukherjee'],
#   'Stars': ['Rajesh Khanna',
#    'Amitabh Bachchan',
#    'Sumita Sanyal',
#    'Ramesh Deo'],
#   'Description': 'The story of a terminally ill man who wishes to live life to the fullest before the inevitable occurs, as told by his best friend.',
#   'Votes': '34,528',
#   'Gross': 0}]

# %% [markdown]
# Check if the data is webscrapped successfully

# %%
data
# Out:
# [{'Rank': '1.',
#   'Title': 'Spider-Man: Across the Spider-Verse',
#   'Year': '(2023)',
#   'PG': 'PG',
#   'Runtime': '140 min',
#   'Genre': 'Animation, Action, Adventure',
#   'IMDB_Rating': '8.9',
#   'Metascore': '86',
#   'Director': ['Joaquim Dos Santos', 'Kemp Powers', 'Justin K. Thompson'],
#   'Stars': ['Shameik Moore',
#    'Hailee Steinfeld',
#    'Brian Tyree Henry',
#    'Luna Lauren Velez'],
#   'Description': 'Miles Morales catapults across the Multiverse, where he encounters a team of Spider-People charged with protecting its very existence. When the heroes clash on how to handle a new threat, Miles must redefine what it means to be a hero.',
#   'Votes': '171,148',
#   'Gross': '#12'},
#  {'Rank': '2.',
#   'Title': 'Titanic',
#   'Year': '(1997)',
#   'PG': 'PG-13',
#   'Runtime': '194 min',
#   'Genre': 'Drama, Romance',
#   'IMDB_Rating': '7.9',
#   'Metascore': '75',
#   'Director': ['James Cameron'],
#   'Stars': ['Leonardo DiCaprio', 'Kate Winslet', 'Billy Zane', 'Kathy Bates'],
#   'Description': 'A seventeen-year-old aristocrat falls in love with a kind but poor artist aboard the luxurious, ill-fated R.M.S. Titanic.',
#   'Votes': '1,228,477',
#   'Gross': '$659.33M'},
#  {'Rank': '3.',
#   'Title': 'Avatar: The Way of Water',
#   'Year': '(2022)',
#   'PG': 'PG-13',
#   'Runtime': '192 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '7.6',
#   'Metascore': '67',
#   'Director': ['James Cameron'],
#   'Stars': ['Sam Worthington',
#    'Zoe Saldana',
#    'Sigourney Weaver',
#    'Stephen Lang'],
#   'Description': "Jake Sully lives with his newfound family formed on the extrasolar moon Pandora. Once a familiar threat returns to finish what was previously started, Jake must work with Neytiri and the army of the Na'vi race to protect their home.",
#   'Votes': '425,970',
#   'Gross': '$659.68M'},
#  {'Rank': '4.',
#   'Title': 'John Wick: Chapter 4',
#   'Year': '(2023)',
#   'PG': 'R',
#   'Runtime': '169 min',
#   'Genre': 'Action, Crime, Thriller',
#   'IMDB_Rating': '7.9',
#   'Metascore': '78',
#   'Director': ['Chad Stahelski'],
#   'Stars': ['Keanu Reeves',
#    'Laurence Fishburne',
#    'George Georgiou',
#    'Lance Reddick'],
#   'Description': 'John Wick uncovers a path to defeating The High Table. But before he can earn his freedom, Wick must face off against a new enemy with powerful alliances across the globe and forces that turn old friends into foes.',
#   'Votes': '232,446',
#   'Gross': 0},
#  {'Rank': '5.',
#   'Title': 'Indiana Jones and the Raiders of the Lost Ark',
#   'Year': '(1981)',
#   'PG': 'PG',
#   'Runtime': '115 min',
#   'Genre': 'Action, Adventure',
#   'IMDB_Rating': '8.4',
#   'Metascore': '85',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Harrison Ford',
#    'Karen Allen',
#    'Paul Freeman',
#    'John Rhys-Davies'],
#   'Description': 'In 1936, archaeologist and adventurer Indiana Jones is hired by the U.S. government to find the Ark of the Covenant before the Nazis can obtain its awesome powers.',
#   'Votes': '998,751',
#   'Gross': '$248.16M'},
#  {'Rank': '6.',
#   'Title': 'Guardians of the Galaxy Vol. 3',
#   'Year': '(2023)',
#   'PG': 'PG-13',
#   'Runtime': '150 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '8.2',
#   'Metascore': '64',
#   'Director': ['James Gunn'],
#   'Stars': ['Chris Pratt',
#    'Chukwudi Iwuji',
#    'Bradley Cooper',
#    'Pom Klementieff'],
#   'Description': 'Still reeling from the loss of Gamora, Peter Quill rallies his team to defend the universe and one of their own - a mission that could mean the end of the Guardians if not successful.',
#   'Votes': '183,601',
#   'Gross': '#170'},
#  {'Rank': '7.',
#   'Title': 'Spider-Man: Into the Spider-Verse',
#   'Year': '(2018)',
#   'PG': 'PG',
#   'Runtime': '117 min',
#   'Genre': 'Animation, Action, Adventure',
#   'IMDB_Rating': '8.4',
#   'Metascore': '87',
#   'Director': ['Bob Persichetti', 'Peter Ramsey', 'Rodney Rothman'],
#   'Stars': ['Shameik Moore',
#    'Jake Johnson',
#    'Hailee Steinfeld',
#    'Mahershala Ali'],
#   'Description': 'Teen Miles Morales becomes the Spider-Man of his universe and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.',
#   'Votes': '603,237',
#   'Gross': '$190.24M'},
#  {'Rank': '8.',
#   'Title': 'Indiana Jones and the Last Crusade',
#   'Year': '(1989)',
#   'PG': 'PG-13',
#   'Runtime': '127 min',
#   'Genre': 'Action, Adventure',
#   'IMDB_Rating': '8.2',
#   'Metascore': '65',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Harrison Ford',
#    'Sean Connery',
#    'Alison Doody',
#    'Denholm Elliott'],
#   'Description': 'In 1938, after his father goes missing while pursuing the Holy Grail, Indiana Jones finds himself up against the Nazis again to stop them from obtaining its powers.',
#   'Votes': '779,756',
#   'Gross': '$197.17M'},
#  {'Rank': '9.',
#   'Title': 'Pulp Fiction',
#   'Year': '(1994)',
#   'PG': 'R',
#   'Runtime': '154 min',
#   'Genre': 'Crime, Drama',
#   'IMDB_Rating': '8.9',
#   'Metascore': '95',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['John Travolta',
#    'Uma Thurman',
#    'Samuel L. Jackson',
#    'Bruce Willis'],
#   'Description': 'The lives of two mob hitmen, a boxer, a gangster and his wife, and a pair of diner bandits intertwine in four tales of violence and redemption.',
#   'Votes': '2,120,228',
#   'Gross': '$107.93M'},
#  {'Rank': '10.',
#   'Title': 'Interstellar',
#   'Year': '(2014)',
#   'PG': 'PG-13',
#   'Runtime': '169 min',
#   'Genre': 'Adventure, Drama, Sci-Fi',
#   'IMDB_Rating': '8.7',
#   'Metascore': '74',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Matthew McConaughey',
#    'Anne Hathaway',
#    'Jessica Chastain',
#    'Mackenzie Foy'],
#   'Description': 'When Earth becomes uninhabitable in the future, a farmer and ex-NASA pilot, Joseph Cooper, is tasked to pilot a spacecraft, along with a team of researchers, to find a new planet for humans.',
#   'Votes': '1,929,940',
#   'Gross': '$188.02M'},
#  {'Rank': '11.',
#   'Title': 'Dune',
#   'Year': '(2021)',
#   'PG': 'PG-13',
#   'Runtime': '155 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '74',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Timothée Chalamet', 'Rebecca Ferguson', 'Zendaya', 'Oscar Isaac'],
#   'Description': "A noble family becomes embroiled in a war for control over the galaxy's most valuable asset while its heir becomes troubled by visions of a dark future.",
#   'Votes': '689,224',
#   'Gross': '$108.33M'},
#  {'Rank': '12.',
#   'Title': 'Top Gun: Maverick',
#   'Year': '(2022)',
#   'PG': 'PG-13',
#   'Runtime': '130 min',
#   'Genre': 'Action, Drama',
#   'IMDB_Rating': '8.3',
#   'Metascore': '78',
#   'Director': ['Joseph Kosinski'],
#   'Stars': ['Tom Cruise', 'Jennifer Connelly', 'Miles Teller', 'Val Kilmer'],
#   'Description': "After thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.",
#   'Votes': '604,132',
#   'Gross': '$718.73M'},
#  {'Rank': '13.',
#   'Title': 'The Shawshank Redemption',
#   'Year': '(1994)',
#   'PG': 'R',
#   'Runtime': '142 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '9.3',
#   'Metascore': '82',
#   'Director': ['Frank Darabont'],
#   'Stars': ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler'],
#   'Description': 'Over the course of several years, two convicts form a friendship, seeking consolation and, eventually, redemption through basic compassion.',
#   'Votes': '2,761,529',
#   'Gross': '$28.34M'},
#  {'Rank': '14.',
#   'Title': 'The Godfather',
#   'Year': '(1972)',
#   'PG': 'R',
#   'Runtime': '175 min',
#   'Genre': 'Crime, Drama',
#   'IMDB_Rating': '9.2',
#   'Metascore': '100',
#   'Director': ['Francis Ford Coppola'],
#   'Stars': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton'],
#   'Description': 'Don Vito Corleone, head of a mafia family, decides to hand over his empire to his youngest son Michael. However, his decision unintentionally puts the lives of his loved ones in grave danger.',
#   'Votes': '1,921,787',
#   'Gross': '$134.97M'},
#  {'Rank': '15.',
#   'Title': 'The Batman',
#   'Year': '(2022)',
#   'PG': 'PG-13',
#   'Runtime': '176 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '72',
#   'Director': ['Matt Reeves'],
#   'Stars': ['Robert Pattinson',
#    'Zoë Kravitz',
#    'Jeffrey Wright',
#    'Colin Farrell'],
#   'Description': "When a sadistic serial killer begins murdering key political figures in Gotham, Batman is forced to investigate the city's hidden corruption and question his family's involvement.",
#   'Votes': '708,217',
#   'Gross': '$369.35M'},
#  {'Rank': '16.',
#   'Title': 'Everything Everywhere All at Once',
#   'Year': '(2022)',
#   'PG': 'R',
#   'Runtime': '139 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '7.8',
#   'Metascore': '81',
#   'Director': ['Daniel Kwan', 'Daniel Scheinert'],
#   'Stars': ['Michelle Yeoh',
#    'Stephanie Hsu',
#    'Jamie Lee Curtis',
#    'Ke Huy Quan'],
#   'Description': 'A middle-aged Chinese immigrant is swept up into an insane adventure in which she alone can save existence by exploring other universes and connecting with the lives she could have led.',
#   'Votes': '459,835',
#   'Gross': '$72.86M'},
#  {'Rank': '17.',
#   'Title': 'The Dark Knight',
#   'Year': '(2008)',
#   'PG': 'PG-13',
#   'Runtime': '152 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '9.0',
#   'Metascore': '84',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Christian Bale',
#    'Heath Ledger',
#    'Aaron Eckhart',
#    'Michael Caine'],
#   'Description': 'When the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#   'Votes': '2,734,530',
#   'Gross': '$534.86M'},
#  {'Rank': '18.',
#   'Title': 'Avatar',
#   'Year': '(2009)',
#   'PG': 'PG-13',
#   'Runtime': '162 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '83',
#   'Director': ['James Cameron'],
#   'Stars': ['Sam Worthington',
#    'Zoe Saldana',
#    'Sigourney Weaver',
#    'Michelle Rodriguez'],
#   'Description': 'A paraplegic Marine dispatched to the moon Pandora on a unique mission becomes torn between following his orders and protecting the world he feels is his home.',
#   'Votes': '1,351,165',
#   'Gross': '$760.51M'},
#  {'Rank': '19.',
#   'Title': 'Inception',
#   'Year': '(2010)',
#   'PG': 'PG-13',
#   'Runtime': '148 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.8',
#   'Metascore': '74',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Leonardo DiCaprio',
#    'Joseph Gordon-Levitt',
#    'Elliot Page',
#    'Ken Watanabe'],
#   'Description': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.',
#   'Votes': '2,426,691',
#   'Gross': '$292.58M'},
#  {'Rank': '20.',
#   'Title': "Harry Potter and the Sorcerer's Stone",
#   'Year': '(2001)',
#   'PG': 'PG',
#   'Runtime': '152 min',
#   'Genre': 'Adventure, Family, Fantasy',
#   'IMDB_Rating': '7.6',
#   'Metascore': '65',
#   'Director': ['Chris Columbus'],
#   'Stars': ['Daniel Radcliffe',
#    'Rupert Grint',
#    'Richard Harris',
#    'Maggie Smith'],
#   'Description': 'An orphaned boy enrolls in a school of wizardry, where he learns the truth about himself, his family and the terrible evil that haunts the magical world.',
#   'Votes': '814,077',
#   'Gross': '$317.58M'},
#  {'Rank': '21.',
#   'Title': 'The Wolf of Wall Street',
#   'Year': '(2013)',
#   'PG': 'R',
#   'Runtime': '180 min',
#   'Genre': 'Biography, Comedy, Crime',
#   'IMDB_Rating': '8.2',
#   'Metascore': '75',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Leonardo DiCaprio',
#    'Jonah Hill',
#    'Margot Robbie',
#    'Matthew McConaughey'],
#   'Description': 'Based on the true story of Jordan Belfort, from his rise to a wealthy stock-broker living the high life to his fall involving crime, corruption and the federal government.',
#   'Votes': '1,473,923',
#   'Gross': '$116.90M'},
#  {'Rank': '22.',
#   'Title': 'Spider-Man: No Way Home',
#   'Year': '(2021)',
#   'PG': 'PG-13',
#   'Runtime': '148 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '8.2',
#   'Metascore': '71',
#   'Director': ['Jon Watts'],
#   'Stars': ['Tom Holland', 'Zendaya', 'Benedict Cumberbatch', 'Jacob Batalon'],
#   'Description': "With Spider-Man's identity now revealed, Peter asks Doctor Strange for help. When a spell goes wrong, dangerous foes from other worlds start to appear, forcing Peter to discover what it truly means to be Spider-Man.",
#   'Votes': '809,640',
#   'Gross': '$804.75M'},
#  {'Rank': '23.',
#   'Title': 'Once Upon a Time in Hollywood',
#   'Year': '(2019)',
#   'PG': 'R',
#   'Runtime': '161 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.6',
#   'Metascore': '83',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['Leonardo DiCaprio', 'Brad Pitt', 'Margot Robbie', 'Emile Hirsch'],
#   'Description': "A faded television actor and his stunt double strive to achieve fame and success in the final years of Hollywood's Golden Age in 1969 Los Angeles.",
#   'Votes': '783,964',
#   'Gross': '$142.50M'},
#  {'Rank': '24.',
#   'Title': 'The Whale',
#   'Year': '(2022)',
#   'PG': 'R',
#   'Runtime': '117 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '60',
#   'Director': ['Darren Aronofsky'],
#   'Stars': ['Brendan Fraser', 'Sadie Sink', 'Ty Simpkins', 'Hong Chau'],
#   'Description': 'A reclusive, morbidly obese English teacher attempts to reconnect with his estranged teenage daughter.',
#   'Votes': '158,828',
#   'Gross': 0},
#  {'Rank': '25.',
#   'Title': 'Jaws',
#   'Year': '(1975)',
#   'PG': 'PG',
#   'Runtime': '124 min',
#   'Genre': 'Adventure, Mystery, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '87',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Roy Scheider',
#    'Robert Shaw',
#    'Richard Dreyfuss',
#    'Lorraine Gary'],
#   'Description': "When a killer shark unleashes chaos on a beach community off Cape Cod, it's up to a local sheriff, a marine biologist, and an old seafarer to hunt the beast down.",
#   'Votes': '628,699',
#   'Gross': '$260.00M'},
#  {'Rank': '26.',
#   'Title': 'Tombstone',
#   'Year': '(1993)',
#   'PG': 'R',
#   'Runtime': '130 min',
#   'Genre': 'Biography, Drama, History',
#   'IMDB_Rating': '7.8',
#   'Metascore': '50',
#   'Director': ['George P. Cosmatos', 'Kevin Jarre'],
#   'Stars': ['Kurt Russell', 'Val Kilmer', 'Sam Elliott', 'Bill Paxton'],
#   'Description': "A successful lawman's plans to retire anonymously in Tombstone, Arizona are disrupted by the kind of outlaws he was famous for eliminating.",
#   'Votes': '157,118',
#   'Gross': '$56.51M'},
#  {'Rank': '27.',
#   'Title': 'The Grand Budapest Hotel',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '99 min',
#   'Genre': 'Adventure, Comedy, Crime',
#   'IMDB_Rating': '8.1',
#   'Metascore': '88',
#   'Director': ['Wes Anderson'],
#   'Stars': ['Ralph Fiennes',
#    'F. Murray Abraham',
#    'Mathieu Amalric',
#    'Adrien Brody'],
#   'Description': "A writer encounters the owner of an aging high-class hotel, who tells him of his early years serving as a lobby boy in the hotel's glorious years under an exceptional concierge.",
#   'Votes': '844,469',
#   'Gross': '$59.10M'},
#  {'Rank': '28.',
#   'Title': 'There Will Be Blood',
#   'Year': '(2007)',
#   'PG': 'R',
#   'Runtime': '158 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.2',
#   'Metascore': '93',
#   'Director': ['Paul Thomas Anderson'],
#   'Stars': ['Daniel Day-Lewis',
#    'Paul Dano',
#    'Ciarán Hinds',
#    'Martin Stringer'],
#   'Description': 'A story of family, religion, hatred, oil and madness, focusing on a turn-of-the-century prospector in the early days of the business.',
#   'Votes': '607,246',
#   'Gross': '$40.22M'},
#  {'Rank': '29.',
#   'Title': 'Avengers: Endgame',
#   'Year': '(2019)',
#   'PG': 'PG-13',
#   'Runtime': '181 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.4',
#   'Metascore': '78',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Stars': ['Robert Downey Jr.',
#    'Chris Evans',
#    'Mark Ruffalo',
#    'Chris Hemsworth'],
#   'Description': "After the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#   'Votes': '1,190,853',
#   'Gross': '$858.37M'},
#  {'Rank': '30.',
#   'Title': 'Django Unchained',
#   'Year': '(2012)',
#   'PG': 'R',
#   'Runtime': '165 min',
#   'Genre': 'Drama, Western',
#   'IMDB_Rating': '8.4',
#   'Metascore': '81',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['Jamie Foxx',
#    'Christoph Waltz',
#    'Leonardo DiCaprio',
#    'Kerry Washington'],
#   'Description': 'With the help of a German bounty-hunter, a freed slave sets out to rescue his wife from a brutal plantation owner in Mississippi.',
#   'Votes': '1,609,238',
#   'Gross': '$162.81M'},
#  {'Rank': '31.',
#   'Title': 'Mission: Impossible - Fallout',
#   'Year': '(2018)',
#   'PG': 'PG-13',
#   'Runtime': '147 min',
#   'Genre': 'Action, Adventure, Thriller',
#   'IMDB_Rating': '7.7',
#   'Metascore': '86',
#   'Director': ['Christopher McQuarrie'],
#   'Stars': ['Tom Cruise', 'Henry Cavill', 'Ving Rhames', 'Simon Pegg'],
#   'Description': 'Ethan Hunt and his IMF team, along with some familiar allies, race against time after a mission gone wrong.',
#   'Votes': '347,859',
#   'Gross': '$220.16M'},
#  {'Rank': '32.',
#   'Title': 'Heat',
#   'Year': '(1995)',
#   'PG': 'R',
#   'Runtime': '170 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '8.3',
#   'Metascore': '76',
#   'Director': ['Michael Mann'],
#   'Stars': ['Al Pacino', 'Robert De Niro', 'Val Kilmer', 'Jon Voight'],
#   'Description': 'A group of high-end professional thieves start to feel the heat from the LAPD when they unknowingly leave a clue at their latest heist.',
#   'Votes': '681,345',
#   'Gross': '$67.44M'},
#  {'Rank': '33.',
#   'Title': 'The Green Mile',
#   'Year': '(1999)',
#   'PG': 'R',
#   'Runtime': '189 min',
#   'Genre': 'Crime, Drama, Fantasy',
#   'IMDB_Rating': '8.6',
#   'Metascore': '61',
#   'Director': ['Frank Darabont'],
#   'Stars': ['Tom Hanks',
#    'Michael Clarke Duncan',
#    'David Morse',
#    'Bonnie Hunt'],
#   'Description': "A tale set on death row in a Southern jail, where gentle giant John possesses the mysterious power to heal people's ailments. When the lead guard, Paul, recognizes John's gift, he tries to help stave off the condemned man's execution.",
#   'Votes': '1,342,705',
#   'Gross': '$136.80M'},
#  {'Rank': '34.',
#   'Title': 'Blade Runner 2049',
#   'Year': '(2017)',
#   'PG': 'R',
#   'Runtime': '164 min',
#   'Genre': 'Action, Drama, Mystery',
#   'IMDB_Rating': '8.0',
#   'Metascore': '81',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Harrison Ford', 'Ryan Gosling', 'Ana de Armas', 'Dave Bautista'],
#   'Description': "Young Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years.",
#   'Votes': '609,366',
#   'Gross': '$92.05M'},
#  {'Rank': '35.',
#   'Title': 'Inglourious Basterds',
#   'Year': '(2009)',
#   'PG': 'R',
#   'Runtime': '153 min',
#   'Genre': 'Adventure, Drama, War',
#   'IMDB_Rating': '8.3',
#   'Metascore': '69',
#   'Director': ['Quentin Tarantino'],
#   'Stars': ['Brad Pitt', 'Diane Kruger', 'Eli Roth', 'Mélanie Laurent'],
#   'Description': "In Nazi-occupied France during World War II, a plan to assassinate Nazi leaders by a group of Jewish U.S. soldiers coincides with a theatre owner's vengeful plans for the same.",
#   'Votes': '1,500,643',
#   'Gross': '$120.54M'},
#  {'Rank': '36.',
#   'Title': 'Little Miss Sunshine',
#   'Year': '(2006)',
#   'PG': 'R',
#   'Runtime': '101 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '80',
#   'Director': ['Jonathan Dayton', 'Valerie Faris'],
#   'Stars': ['Steve Carell',
#    'Toni Collette',
#    'Greg Kinnear',
#    'Abigail Breslin'],
#   'Description': 'A family determined to get their young daughter into the finals of a beauty pageant take a cross-country trip in their VW bus.',
#   'Votes': '498,135',
#   'Gross': '$59.89M'},
#  {'Rank': '37.',
#   'Title': 'Goodfellas',
#   'Year': '(1990)',
#   'PG': 'R',
#   'Runtime': '145 min',
#   'Genre': 'Biography, Crime, Drama',
#   'IMDB_Rating': '8.7',
#   'Metascore': '92',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Robert De Niro', 'Ray Liotta', 'Joe Pesci', 'Lorraine Bracco'],
#   'Description': 'The story of Henry Hill and his life in the mafia, covering his relationship with his wife Karen and his mob partners Jimmy Conway and Tommy DeVito.',
#   'Votes': '1,198,618',
#   'Gross': '$46.84M'},
#  {'Rank': '38.',
#   'Title': 'Prisoners',
#   'Year': '(2013)',
#   'PG': 'R',
#   'Runtime': '153 min',
#   'Genre': 'Crime, Drama, Mystery',
#   'IMDB_Rating': '8.1',
#   'Metascore': '70',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Hugh Jackman', 'Jake Gyllenhaal', 'Viola Davis', 'Melissa Leo'],
#   'Description': "When Keller Dover's daughter and her friend go missing, he takes matters into his own hands as the police pursue multiple leads and the pressure mounts.",
#   'Votes': '752,979',
#   'Gross': '$61.00M'},
#  {'Rank': '39.',
#   'Title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'Year': '(2001)',
#   'PG': 'PG-13',
#   'Runtime': '178 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.8',
#   'Metascore': '92',
#   'Director': ['Peter Jackson'],
#   'Stars': ['Elijah Wood', 'Ian McKellen', 'Orlando Bloom', 'Sean Bean'],
#   'Description': 'A meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.',
#   'Votes': '1,924,179',
#   'Gross': '$315.54M'},
#  {'Rank': '40.',
#   'Title': 'Apocalypse Now',
#   'Year': '(1979)',
#   'PG': 'R',
#   'Runtime': '147 min',
#   'Genre': 'Drama, Mystery, War',
#   'IMDB_Rating': '8.4',
#   'Metascore': '94',
#   'Director': ['Francis Ford Coppola'],
#   'Stars': ['Martin Sheen',
#    'Marlon Brando',
#    'Robert Duvall',
#    'Frederic Forrest'],
#   'Description': 'A U.S. Army officer serving in Vietnam is tasked with assassinating a renegade Special Forces Colonel who sees himself as a god.',
#   'Votes': '684,966',
#   'Gross': '$83.47M'},
#  {'Rank': '41.',
#   'Title': 'Puss in Boots: The Last Wish',
#   'Year': '(2022)',
#   'PG': 'PG',
#   'Runtime': '102 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '73',
#   'Director': ['Joel Crawford', 'Januel Mercado'],
#   'Stars': ['Antonio Banderas',
#    'Salma Hayek',
#    'Harvey Guillén',
#    'Florence Pugh'],
#   'Description': 'When Puss in Boots discovers that his passion for adventure has taken its toll and he has burned through eight of his nine lives, he launches an epic journey to restore them by finding the mythical Last Wish.',
#   'Votes': '138,258',
#   'Gross': '$168.46M'},
#  {'Rank': '42.',
#   'Title': 'Aliens',
#   'Year': '(1986)',
#   'PG': 'R',
#   'Runtime': '137 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.4',
#   'Metascore': '84',
#   'Director': ['James Cameron'],
#   'Stars': ['Sigourney Weaver', 'Michael Biehn', 'Carrie Henn', 'Paul Reiser'],
#   'Description': 'Decades after surviving the Nostromo incident, Ellen Ripley is sent out to re-establish contact with a terraforming colony but finds herself battling the Alien Queen and her offspring.',
#   'Votes': '735,665',
#   'Gross': '$85.16M'},
#  {'Rank': '43.',
#   'Title': 'Jurassic Park',
#   'Year': '(1993)',
#   'PG': 'PG-13',
#   'Runtime': '127 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.2',
#   'Metascore': '68',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Sam Neill',
#    'Laura Dern',
#    'Jeff Goldblum',
#    'Richard Attenborough'],
#   'Description': "A pragmatic paleontologist touring an almost complete theme park on an island in Central America is tasked with protecting a couple of kids after a power failure causes the park's cloned dinosaurs to run loose.",
#   'Votes': '1,020,515',
#   'Gross': '$402.45M'},
#  {'Rank': '44.',
#   'Title': 'American Psycho',
#   'Year': '(2000)',
#   'PG': 'R',
#   'Runtime': '102 min',
#   'Genre': 'Crime, Drama, Horror',
#   'IMDB_Rating': '7.6',
#   'Metascore': '64',
#   'Director': ['Mary Harron'],
#   'Stars': ['Christian Bale', 'Justin Theroux', 'Josh Lucas', 'Bill Sage'],
#   'Description': 'A wealthy New York City investment banking executive, Patrick Bateman, hides his alternate psychopathic ego from his co-workers and friends as he delves deeper into his violent, hedonistic fantasies.',
#   'Votes': '662,016',
#   'Gross': '$15.07M'},
#  {'Rank': '45.',
#   'Title': 'Dunkirk',
#   'Year': '(2017)',
#   'PG': 'PG-13',
#   'Runtime': '106 min',
#   'Genre': 'Action, Drama, History',
#   'IMDB_Rating': '7.8',
#   'Metascore': '94',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Fionn Whitehead', 'Barry Keoghan', 'Mark Rylance', 'Tom Hardy'],
#   'Description': 'Allied soldiers from Belgium, the British Commonwealth and Empire, and France are surrounded by the German Army and evacuated during a fierce battle in World War II.',
#   'Votes': '686,811',
#   'Gross': '$188.37M'},
#  {'Rank': '46.',
#   'Title': 'Back to the Future',
#   'Year': '(1985)',
#   'PG': 'PG',
#   'Runtime': '116 min',
#   'Genre': 'Adventure, Comedy, Sci-Fi',
#   'IMDB_Rating': '8.5',
#   'Metascore': '87',
#   'Director': ['Robert Zemeckis'],
#   'Stars': ['Michael J. Fox',
#    'Christopher Lloyd',
#    'Lea Thompson',
#    'Crispin Glover'],
#   'Description': 'Marty McFly, a 17-year-old high school student, is accidentally sent 30 years into the past in a time-traveling DeLorean invented by his close friend, the maverick scientist Doc Brown.',
#   'Votes': '1,246,408',
#   'Gross': '$210.61M'},
#  {'Rank': '47.',
#   'Title': 'A Bronx Tale',
#   'Year': '(1993)',
#   'PG': 'R',
#   'Runtime': '121 min',
#   'Genre': 'Crime, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '80',
#   'Director': ['Robert De Niro'],
#   'Stars': ['Robert De Niro',
#    'Chazz Palminteri',
#    'Lillo Brancato',
#    'Francis Capra'],
#   'Description': 'A father becomes worried when a local gangster befriends his son in the Bronx in the 1960s.',
#   'Votes': '150,573',
#   'Gross': '$17.27M'},
#  {'Rank': '48.',
#   'Title': 'Terminator 2: Judgment Day',
#   'Year': '(1991)',
#   'PG': 'R',
#   'Runtime': '137 min',
#   'Genre': 'Action, Sci-Fi',
#   'IMDB_Rating': '8.6',
#   'Metascore': '75',
#   'Director': ['James Cameron'],
#   'Stars': ['Arnold Schwarzenegger',
#    'Linda Hamilton',
#    'Edward Furlong',
#    'Robert Patrick'],
#   'Description': 'A cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten year old son John from an even more advanced and powerful cyborg.',
#   'Votes': '1,128,937',
#   'Gross': '$204.84M'},
#  {'Rank': '49.',
#   'Title': 'Se7en',
#   'Year': '(1995)',
#   'PG': 'R',
#   'Runtime': '127 min',
#   'Genre': 'Crime, Drama, Mystery',
#   'IMDB_Rating': '8.6',
#   'Metascore': '65',
#   'Director': ['David Fincher'],
#   'Stars': ['Morgan Freeman',
#    'Brad Pitt',
#    'Kevin Spacey',
#    'Andrew Kevin Walker'],
#   'Description': 'Two detectives, a rookie and a veteran, hunt a serial killer who uses the seven deadly sins as his motives.',
#   'Votes': '1,707,428',
#   'Gross': '$100.13M'},
#  {'Rank': '50.',
#   'Title': 'The Departed',
#   'Year': '(2006)',
#   'PG': 'R',
#   'Runtime': '151 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.5',
#   'Metascore': '85',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Leonardo DiCaprio',
#    'Matt Damon',
#    'Jack Nicholson',
#    'Mark Wahlberg'],
#   'Description': 'An undercover cop and a mole in the police attempt to identify each other while infiltrating an Irish gang in South Boston.',
#   'Votes': '1,363,031',
#   'Gross': '$132.38M'},
#  {'Rank': '51.',
#   'Title': 'Fight Club',
#   'Year': '(1999)',
#   'PG': 'R',
#   'Runtime': '139 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.8',
#   'Metascore': '67',
#   'Director': ['David Fincher'],
#   'Stars': ['Brad Pitt', 'Edward Norton', 'Meat Loaf', 'Zach Grenier'],
#   'Description': 'An insomniac office worker and a devil-may-care soap maker form an underground fight club that evolves into much more.',
#   'Votes': '2,198,847',
#   'Gross': '$37.03M'},
#  {'Rank': '52.',
#   'Title': 'Gladiator',
#   'Year': '(2000)',
#   'PG': 'R',
#   'Runtime': '155 min',
#   'Genre': 'Action, Adventure, Drama',
#   'IMDB_Rating': '8.5',
#   'Metascore': '67',
#   'Director': ['Ridley Scott'],
#   'Stars': ['Russell Crowe',
#    'Joaquin Phoenix',
#    'Connie Nielsen',
#    'Oliver Reed'],
#   'Description': 'A former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.',
#   'Votes': '1,543,280',
#   'Gross': '$187.71M'},
#  {'Rank': '53.',
#   'Title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'Year': '(2003)',
#   'PG': 'PG-13',
#   'Runtime': '143 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '8.1',
#   'Metascore': '63',
#   'Director': ['Gore Verbinski'],
#   'Stars': ['Johnny Depp',
#    'Geoffrey Rush',
#    'Orlando Bloom',
#    'Keira Knightley'],
#   'Description': 'Blacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.',
#   'Votes': '1,159,407',
#   'Gross': '$305.41M'},
#  {'Rank': '54.',
#   'Title': 'Blade Runner',
#   'Year': '(1982)',
#   'PG': 'R',
#   'Runtime': '117 min',
#   'Genre': 'Action, Drama, Sci-Fi',
#   'IMDB_Rating': '8.1',
#   'Metascore': '84',
#   'Director': ['Ridley Scott'],
#   'Stars': ['Harrison Ford',
#    'Rutger Hauer',
#    'Sean Young',
#    'Edward James Olmos'],
#   'Description': 'A blade runner must pursue and terminate four replicants who stole a ship in space and have returned to Earth to find their creator.',
#   'Votes': '791,709',
#   'Gross': '$32.87M'},
#  {'Rank': '55.',
#   'Title': 'The Terminator',
#   'Year': '(1984)',
#   'PG': 'R',
#   'Runtime': '107 min',
#   'Genre': 'Action, Sci-Fi',
#   'IMDB_Rating': '8.1',
#   'Metascore': '84',
#   'Director': ['James Cameron'],
#   'Stars': ['Arnold Schwarzenegger',
#    'Linda Hamilton',
#    'Michael Biehn',
#    'Paul Winfield'],
#   'Description': "A human soldier is sent from 2029 to 1984 to stop an almost indestructible cyborg killing machine, sent from the same year, which has been programmed to execute a young woman whose unborn son is the key to humanity's future salvation.",
#   'Votes': '890,190',
#   'Gross': '$38.40M'},
#  {'Rank': '56.',
#   'Title': "Zack Snyder's Justice League",
#   'Year': '(2021)',
#   'PG': 'R',
#   'Runtime': '242 min',
#   'Genre': 'Action, Adventure, Fantasy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '54',
#   'Director': ['Zack Snyder'],
#   'Stars': ['Henry Cavill', 'Ben Affleck', 'Gal Gadot', 'Amy Adams'],
#   'Description': "Determined to ensure that Superman's ultimate sacrifice wasn't in vain, Bruce Wayne recruits a team of metahumans to protect the world from an approaching threat of catastrophic proportions.",
#   'Votes': '416,925',
#   'Gross': 0},
#  {'Rank': '57.',
#   'Title': 'Joker',
#   'Year': '(I) (2019)',
#   'PG': 'R',
#   'Runtime': '122 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.4',
#   'Metascore': '59',
#   'Director': ['Todd Phillips'],
#   'Stars': ['Joaquin Phoenix',
#    'Robert De Niro',
#    'Zazie Beetz',
#    'Frances Conroy'],
#   'Description': "The rise of Arthur Fleck, from aspiring stand-up comedian and pariah to Gotham's clown prince and leader of the revolution.",
#   'Votes': '1,367,042',
#   'Gross': '$335.45M'},
#  {'Rank': '58.',
#   'Title': 'Saving Private Ryan',
#   'Year': '(1998)',
#   'PG': 'R',
#   'Runtime': '169 min',
#   'Genre': 'Drama, War',
#   'IMDB_Rating': '8.6',
#   'Metascore': '91',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Tom Hanks', 'Matt Damon', 'Tom Sizemore', 'Edward Burns'],
#   'Description': 'Following the Normandy Landings, a group of U.S. soldiers go behind enemy lines to retrieve a paratrooper whose brothers have been killed in action.',
#   'Votes': '1,430,509',
#   'Gross': '$216.54M'},
#  {'Rank': '59.',
#   'Title': 'The Matrix',
#   'Year': '(1999)',
#   'PG': 'R',
#   'Runtime': '136 min',
#   'Genre': 'Action, Sci-Fi',
#   'IMDB_Rating': '8.7',
#   'Metascore': '73',
#   'Director': ['Lana Wachowski', 'Lilly Wachowski'],
#   'Stars': ['Keanu Reeves',
#    'Laurence Fishburne',
#    'Carrie-Anne Moss',
#    'Hugo Weaving'],
#   'Description': 'When a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.',
#   'Votes': '1,967,595',
#   'Gross': '$171.48M'},
#  {'Rank': '60.',
#   'Title': 'Forrest Gump',
#   'Year': '(1994)',
#   'PG': 'PG-13',
#   'Runtime': '142 min',
#   'Genre': 'Drama, Romance',
#   'IMDB_Rating': '8.8',
#   'Metascore': '82',
#   'Director': ['Robert Zemeckis'],
#   'Stars': ['Tom Hanks', 'Robin Wright', 'Gary Sinise', 'Sally Field'],
#   'Description': "The history of the United States from the 1950s to the '70s unfolds from the perspective of an Alabama man with an IQ of 75, who yearns to be reunited with his childhood sweetheart.",
#   'Votes': '2,147,986',
#   'Gross': '$330.25M'},
#  {'Rank': '61.',
#   'Title': 'Moonrise Kingdom',
#   'Year': '(2012)',
#   'PG': 'PG-13',
#   'Runtime': '94 min',
#   'Genre': 'Comedy, Drama, Family',
#   'IMDB_Rating': '7.8',
#   'Metascore': '84',
#   'Director': ['Wes Anderson'],
#   'Stars': ['Jared Gilman', 'Kara Hayward', 'Bruce Willis', 'Bill Murray'],
#   'Description': 'A pair of young lovers flee their New England town, which causes a local search party to fan out to find them.',
#   'Votes': '358,866',
#   'Gross': '$45.51M'},
#  {'Rank': '62.',
#   'Title': 'Guardians of the Galaxy',
#   'Year': '(2014)',
#   'PG': 'PG-13',
#   'Runtime': '121 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '8.0',
#   'Metascore': '76',
#   'Director': ['James Gunn'],
#   'Stars': ['Chris Pratt', 'Vin Diesel', 'Bradley Cooper', 'Zoe Saldana'],
#   'Description': 'A group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.',
#   'Votes': '1,226,843',
#   'Gross': '$333.18M'},
#  {'Rank': '63.',
#   'Title': 'Alien',
#   'Year': '(1979)',
#   'PG': 'R',
#   'Runtime': '117 min',
#   'Genre': 'Horror, Sci-Fi',
#   'IMDB_Rating': '8.5',
#   'Metascore': '89',
#   'Director': ['Ridley Scott'],
#   'Stars': ['Sigourney Weaver',
#    'Tom Skerritt',
#    'John Hurt',
#    'Veronica Cartwright'],
#   'Description': 'The crew of a commercial spacecraft encounter a deadly lifeform after investigating an unknown transmission.',
#   'Votes': '907,857',
#   'Gross': '$78.90M'},
#  {'Rank': '64.',
#   'Title': 'Shutter Island',
#   'Year': '(2010)',
#   'PG': 'R',
#   'Runtime': '138 min',
#   'Genre': 'Mystery, Thriller',
#   'IMDB_Rating': '8.2',
#   'Metascore': '63',
#   'Director': ['Martin Scorsese'],
#   'Stars': ['Leonardo DiCaprio',
#    'Emily Mortimer',
#    'Mark Ruffalo',
#    'Ben Kingsley'],
#   'Description': 'Teddy Daniels and Chuck Aule, two US marshals, are sent to an asylum on a remote island in order to investigate the disappearance of a patient, where Teddy uncovers a shocking truth about the place.',
#   'Votes': '1,370,138',
#   'Gross': '$128.01M'},
#  {'Rank': '65.',
#   'Title': 'Parasite',
#   'Year': '(2019)',
#   'PG': 'R',
#   'Runtime': '132 min',
#   'Genre': 'Drama, Thriller',
#   'IMDB_Rating': '8.5',
#   'Metascore': '96',
#   'Director': ['Bong Joon Ho'],
#   'Stars': ['Song Kang-ho', 'Lee Sun-kyun', 'Cho Yeo-jeong', 'Choi Woo-sik'],
#   'Description': 'Greed and class discrimination threaten the newly formed symbiotic relationship between the wealthy Park family and the destitute Kim clan.',
#   'Votes': '864,187',
#   'Gross': '$53.37M'},
#  {'Rank': '66.',
#   'Title': 'The Silence of the Lambs',
#   'Year': '(1991)',
#   'PG': 'R',
#   'Runtime': '118 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.6',
#   'Metascore': '86',
#   'Director': ['Jonathan Demme'],
#   'Stars': ['Jodie Foster',
#    'Anthony Hopkins',
#    'Lawrence A. Bonney',
#    'Kasi Lemmons'],
#   'Description': 'A young F.B.I. cadet must receive the help of an incarcerated and manipulative cannibal killer to help catch another serial killer, a madman who skins his victims.',
#   'Votes': '1,474,805',
#   'Gross': '$130.74M'},
#  {'Rank': '67.',
#   'Title': 'The Breakfast Club',
#   'Year': '(1985)',
#   'PG': 'R',
#   'Runtime': '97 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '66',
#   'Director': ['John Hughes'],
#   'Stars': ['Emilio Estevez', 'Judd Nelson', 'Molly Ringwald', 'Ally Sheedy'],
#   'Description': 'Five high school students meet in Saturday detention and discover how they have a great deal more in common than they thought.',
#   'Votes': '417,371',
#   'Gross': '$45.88M'},
#  {'Rank': '68.',
#   'Title': "Schindler's List",
#   'Year': '(1993)',
#   'PG': 'R',
#   'Runtime': '195 min',
#   'Genre': 'Biography, Drama, History',
#   'IMDB_Rating': '9.0',
#   'Metascore': '95',
#   'Director': ['Steven Spielberg'],
#   'Stars': ['Liam Neeson',
#    'Ralph Fiennes',
#    'Ben Kingsley',
#    'Caroline Goodall'],
#   'Description': 'In German-occupied Poland during World War II, industrialist Oskar Schindler gradually becomes concerned for his Jewish workforce after witnessing their persecution by the Nazis.',
#   'Votes': '1,391,455',
#   'Gross': '$96.90M'},
#  {'Rank': '69.',
#   'Title': 'The Prestige',
#   'Year': '(2006)',
#   'PG': 'PG-13',
#   'Runtime': '130 min',
#   'Genre': 'Drama, Mystery, Sci-Fi',
#   'IMDB_Rating': '8.5',
#   'Metascore': '66',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Christian Bale',
#    'Hugh Jackman',
#    'Scarlett Johansson',
#    'Michael Caine'],
#   'Description': 'After a tragic accident, two stage magicians in 1890s London engage in a battle to create the ultimate illusion while sacrificing everything they have to outwit each other.',
#   'Votes': '1,371,346',
#   'Gross': '$53.09M'},
#  {'Rank': '70.',
#   'Title': 'The Banshees of Inisherin',
#   'Year': '(2022)',
#   'PG': 'R',
#   'Runtime': '114 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '87',
#   'Director': ['Martin McDonagh'],
#   'Stars': ['Colin Farrell', 'Brendan Gleeson', 'Kerry Condon', 'Pat Shortt'],
#   'Description': 'Two lifelong friends find themselves at an impasse when one abruptly ends their relationship, with alarming consequences for both of them.',
#   'Votes': '215,130',
#   'Gross': 0},
#  {'Rank': '71.',
#   'Title': 'The Goonies',
#   'Year': '(1985)',
#   'PG': 'PG',
#   'Runtime': '114 min',
#   'Genre': 'Adventure, Comedy, Family',
#   'IMDB_Rating': '7.7',
#   'Metascore': '62',
#   'Director': ['Richard Donner'],
#   'Stars': ['Sean Astin', 'Josh Brolin', 'Jeff Cohen', 'Corey Feldman'],
#   'Description': "A group of young misfits called The Goonies discover an ancient map and set out on an adventure to find a legendary pirate's long-lost treasure.",
#   'Votes': '286,407',
#   'Gross': '$61.50M'},
#  {'Rank': '72.',
#   'Title': 'The Gentlemen',
#   'Year': '(2019)',
#   'PG': 'R',
#   'Runtime': '113 min',
#   'Genre': 'Action, Comedy, Crime',
#   'IMDB_Rating': '7.8',
#   'Metascore': '51',
#   'Director': ['Guy Ritchie'],
#   'Stars': ['Matthew McConaughey',
#    'Charlie Hunnam',
#    'Michelle Dockery',
#    'Jeremy Strong'],
#   'Description': 'An American expat tries to sell off his highly profitable marijuana empire in London, triggering plots, schemes, bribery and blackmail in an attempt to steal his domain out from under him.',
#   'Votes': '363,708',
#   'Gross': '$36.47M'},
#  {'Rank': '73.',
#   'Title': 'Whiplash',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '106 min',
#   'Genre': 'Drama, Music',
#   'IMDB_Rating': '8.5',
#   'Metascore': '89',
#   'Director': ['Damien Chazelle'],
#   'Stars': ['Miles Teller', 'J.K. Simmons', 'Melissa Benoist', 'Paul Reiser'],
#   'Description': "A promising young drummer enrolls at a cut-throat music conservatory where his dreams of greatness are mentored by an instructor who will stop at nothing to realize a student's potential.",
#   'Votes': '912,552',
#   'Gross': '$13.09M'},
#  {'Rank': '74.',
#   'Title': 'The Dark Knight Rises',
#   'Year': '(2012)',
#   'PG': 'PG-13',
#   'Runtime': '164 min',
#   'Genre': 'Action, Drama, Thriller',
#   'IMDB_Rating': '8.4',
#   'Metascore': '78',
#   'Director': ['Christopher Nolan'],
#   'Stars': ['Christian Bale', 'Tom Hardy', 'Anne Hathaway', 'Gary Oldman'],
#   'Description': "Eight years after the Joker's reign of chaos, Batman is coerced out of exile with the assistance of the mysterious Selina Kyle in order to defend Gotham City from the vicious guerrilla terrorist Bane.",
#   'Votes': '1,750,551',
#   'Gross': '$448.14M'},
#  {'Rank': '75.',
#   'Title': 'Aftersun',
#   'Year': '(II) (2022)',
#   'PG': 'R',
#   'Runtime': '102 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '95',
#   'Director': ['Charlotte Wells'],
#   'Stars': ['Paul Mescal',
#    'Frankie Corio',
#    'Celia Rowlson-Hall',
#    'Sally Messham'],
#   'Description': "Sophie reflects on the shared joy and private melancholy of a holiday she took with her father twenty years earlier. Memories real and imagined fill the gaps between as she tries to reconcile the father she knew with the man she didn't...",
#   'Votes': '67,019',
#   'Gross': 0},
#  {'Rank': '76.',
#   'Title': 'Avengers: Infinity War',
#   'Year': '(2018)',
#   'PG': 'PG-13',
#   'Runtime': '149 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.4',
#   'Metascore': '68',
#   'Director': ['Anthony Russo', 'Joe Russo'],
#   'Stars': ['Robert Downey Jr.',
#    'Chris Hemsworth',
#    'Mark Ruffalo',
#    'Chris Evans'],
#   'Description': 'The Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.',
#   'Votes': '1,133,431',
#   'Gross': '$678.82M'},
#  {'Rank': '77.',
#   'Title': 'Get Out',
#   'Year': '(I) (2017)',
#   'PG': 'R',
#   'Runtime': '104 min',
#   'Genre': 'Horror, Mystery, Thriller',
#   'IMDB_Rating': '7.8',
#   'Metascore': '85',
#   'Director': ['Jordan Peele'],
#   'Stars': ['Daniel Kaluuya',
#    'Allison Williams',
#    'Bradley Whitford',
#    'Catherine Keener'],
#   'Description': "A young African-American visits his White girlfriend's parents for the weekend, where his simmering uneasiness about their reception of him eventually reaches a boiling point.",
#   'Votes': '645,268',
#   'Gross': '$176.04M'},
#  {'Rank': '78.',
#   'Title': 'Kingsman: The Secret Service',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '129 min',
#   'Genre': 'Action, Adventure, Comedy',
#   'IMDB_Rating': '7.7',
#   'Metascore': '60',
#   'Director': ['Matthew Vaughn'],
#   'Stars': ['Colin Firth',
#    'Taron Egerton',
#    'Samuel L. Jackson',
#    'Michael Caine'],
#   'Description': "A spy organisation recruits a promising street kid into the agency's training program, while a global threat emerges from a twisted tech genius.",
#   'Votes': '690,134',
#   'Gross': '$128.26M'},
#  {'Rank': '79.',
#   'Title': 'The Fifth Element',
#   'Year': '(1997)',
#   'PG': 'PG-13',
#   'Runtime': '126 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '7.6',
#   'Metascore': '52',
#   'Director': ['Luc Besson'],
#   'Stars': ['Bruce Willis', 'Milla Jovovich', 'Gary Oldman', 'Ian Holm'],
#   'Description': 'In the colorful future, a cab driver unwittingly becomes the central figure in the search for a legendary cosmic weapon to keep Evil and Mr. Zorg at bay.',
#   'Votes': '487,977',
#   'Gross': '$63.54M'},
#  {'Rank': '80.',
#   'Title': 'Arrival',
#   'Year': '(II) (2016)',
#   'PG': 'PG-13',
#   'Runtime': '116 min',
#   'Genre': 'Drama, Mystery, Sci-Fi',
#   'IMDB_Rating': '7.9',
#   'Metascore': '81',
#   'Director': ['Denis Villeneuve'],
#   'Stars': ['Amy Adams',
#    'Jeremy Renner',
#    'Forest Whitaker',
#    'Michael Stuhlbarg'],
#   'Description': 'A linguist works with the military to communicate with alien lifeforms after twelve mysterious spacecraft appear around the world.',
#   'Votes': '723,892',
#   'Gross': '$100.55M'},
#  {'Rank': '81.',
#   'Title': 'Léon: The Professional',
#   'Year': '(1994)',
#   'PG': 'R',
#   'Runtime': '110 min',
#   'Genre': 'Action, Crime, Drama',
#   'IMDB_Rating': '8.5',
#   'Metascore': '64',
#   'Director': ['Luc Besson'],
#   'Stars': ['Jean Reno', 'Gary Oldman', 'Natalie Portman', 'Danny Aiello'],
#   'Description': "12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.",
#   'Votes': '1,195,152',
#   'Gross': '$19.50M'},
#  {'Rank': '82.',
#   'Title': 'Fantastic Mr. Fox',
#   'Year': '(2009)',
#   'PG': 'PG',
#   'Runtime': '87 min',
#   'Genre': 'Animation, Adventure, Comedy',
#   'IMDB_Rating': '7.9',
#   'Metascore': '83',
#   'Director': ['Wes Anderson'],
#   'Stars': ['George Clooney',
#    'Meryl Streep',
#    'Bill Murray',
#    'Jason Schwartzman'],
#   'Description': "An urbane fox cannot resist returning to his farm raiding ways and then must help his community survive the farmers' retaliation.",
#   'Votes': '249,836',
#   'Gross': '$21.00M'},
#  {'Rank': '83.',
#   'Title': 'Deadpool',
#   'Year': '(2016)',
#   'PG': 'R',
#   'Runtime': '108 min',
#   'Genre': 'Action, Comedy',
#   'IMDB_Rating': '8.0',
#   'Metascore': '65',
#   'Director': ['Tim Miller'],
#   'Stars': ['Ryan Reynolds', 'Morena Baccarin', 'T.J. Miller', 'Ed Skrein'],
#   'Description': 'A wisecracking mercenary gets experimented on and becomes immortal but ugly, and sets out to track down the man who ruined his looks.',
#   'Votes': '1,073,858',
#   'Gross': '$363.07M'},
#  {'Rank': '84.',
#   'Title': 'Mad Max: Fury Road',
#   'Year': '(2015)',
#   'PG': 'R',
#   'Runtime': '120 min',
#   'Genre': 'Action, Adventure, Sci-Fi',
#   'IMDB_Rating': '8.1',
#   'Metascore': '90',
#   'Director': ['George Miller'],
#   'Stars': ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult', 'Zoë Kravitz'],
#   'Description': 'In a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper and a drifter named Max.',
#   'Votes': '1,035,264',
#   'Gross': '$154.06M'},
#  {'Rank': '85.',
#   'Title': 'The Shining',
#   'Year': '(1980)',
#   'PG': 'R',
#   'Runtime': '146 min',
#   'Genre': 'Drama, Horror',
#   'IMDB_Rating': '8.4',
#   'Metascore': '66',
#   'Director': ['Stanley Kubrick'],
#   'Stars': ['Jack Nicholson',
#    'Shelley Duvall',
#    'Danny Lloyd',
#    'Scatman Crothers'],
#   'Description': 'A family heads to an isolated hotel for the winter where a sinister presence influences the father into violence, while his psychic son sees horrific forebodings from both past and future.',
#   'Votes': '1,054,826',
#   'Gross': '$44.02M'},
#  {'Rank': '86.',
#   'Title': 'Gone Girl',
#   'Year': '(2014)',
#   'PG': 'R',
#   'Runtime': '149 min',
#   'Genre': 'Drama, Mystery, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '79',
#   'Director': ['David Fincher'],
#   'Stars': ['Ben Affleck',
#    'Rosamund Pike',
#    'Neil Patrick Harris',
#    'Tyler Perry'],
#   'Description': "With his wife's disappearance having become the focus of an intense media circus, a man sees the spotlight turned on him when it's suspected that he may not be innocent.",
#   'Votes': '1,013,647',
#   'Gross': '$167.77M'},
#  {'Rank': '87.',
#   'Title': 'Full Metal Jacket',
#   'Year': '(1987)',
#   'PG': 'R',
#   'Runtime': '116 min',
#   'Genre': 'Drama, War',
#   'IMDB_Rating': '8.3',
#   'Metascore': '78',
#   'Director': ['Stanley Kubrick'],
#   'Stars': ['Matthew Modine',
#    'R. Lee Ermey',
#    "Vincent D'Onofrio",
#    'Adam Baldwin'],
#   'Description': 'A pragmatic U.S. Marine observes the dehumanizing effects the Vietnam War has on his fellow recruits from their brutal boot camp training to the bloody street fighting in Hue.',
#   'Votes': '762,076',
#   'Gross': '$46.36M'},
#  {'Rank': '88.',
#   'Title': 'No Country for Old Men',
#   'Year': '(2007)',
#   'PG': 'R',
#   'Runtime': '122 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.2',
#   'Metascore': '92',
#   'Director': ['Ethan Coen', 'Joel Coen'],
#   'Stars': ['Tommy Lee Jones',
#    'Javier Bardem',
#    'Josh Brolin',
#    'Woody Harrelson'],
#   'Description': 'Violence and mayhem ensue after a hunter stumbles upon a drug deal gone wrong and more than two million dollars in cash near the Rio Grande.',
#   'Votes': '1,006,987',
#   'Gross': '$74.28M'},
#  {'Rank': '89.',
#   'Title': 'Rain Man',
#   'Year': '(1988)',
#   'PG': 'R',
#   'Runtime': '133 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '65',
#   'Director': ['Barry Levinson'],
#   'Stars': ['Dustin Hoffman',
#    'Tom Cruise',
#    'Valeria Golino',
#    'Gerald R. Molen'],
# ...
#    'Trisha Krishnan',
#    'Gouri Kishan'],
#   'Description': 'Two high school sweethearts meet at a reunion after 22 years and reminisce about their past.',
#   'Votes': '33,416',
#   'Gross': 0},
#  {'Rank': '969.',
#   'Title': 'Tae Guk Gi: The Brotherhood of War',
#   'Year': '(2004)',
#   'PG': 'R',
#   'Runtime': '140 min',
#   'Genre': 'Action, Drama, War',
#   'IMDB_Rating': '8.0',
#   'Metascore': '64',
#   'Director': ['Je-kyu Kang'],
#   'Stars': ['Jang Dong-Gun', 'Won Bin', 'Eun-ju Lee', 'Hyeong-jin Kong'],
#   'Description': 'When two brothers are forced to fight in the Korean War, the elder decides to take the riskiest missions if it will help shield the younger from battle.',
#   'Votes': '40,430',
#   'Gross': '$1.11M'},
#  {'Rank': '970.',
#   'Title': 'Tangerines',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '87 min',
#   'Genre': 'Drama, War',
#   'IMDB_Rating': '8.1',
#   'Metascore': '73',
#   'Director': ['Zaza Urushadze'],
#   'Stars': ['Lembit Ulfsak',
#    'Elmo Nüganen',
#    'Giorgi Nakashidze',
#    'Misha Meskhi'],
#   'Description': 'In 1992, war rages in Abkhazia, a breakaway region of Georgia. An Estonian man Ivo has decided to stay behind and harvest his crops of tangerines. In a bloody conflict at his door, a wounded man is left behind, and Ivo takes him in.',
#   'Votes': '47,668',
#   'Gross': '$0.14M'},
#  {'Rank': '971.',
#   'Title': 'A Night at the Opera',
#   'Year': '(1935)',
#   'PG': 'Passed',
#   'Runtime': '96 min',
#   'Genre': 'Comedy, Music, Musical',
#   'IMDB_Rating': '7.8',
#   'Metascore': '0',
#   'Director': ['Sam Wood', 'Edmund Goulding'],
#   'Stars': ['Groucho Marx', 'Chico Marx', 'Harpo Marx', 'Kitty Carlisle'],
#   'Description': 'A sly business manager and the wacky friends of two opera singers in Italy help them achieve success in America while humiliating their stuffy and snobbish enemies.',
#   'Votes': '33,833',
#   'Gross': '$2.54M'},
#  {'Rank': '972.',
#   'Title': 'Winter Light',
#   'Year': '(1963)',
#   'PG': 'Not Rated',
#   'Runtime': '81 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Ingmar Bergman'],
#   'Stars': ['Ingrid Thulin',
#    'Gunnar Björnstrand',
#    'Gunnel Lindblom',
#    'Max von Sydow'],
#   'Description': 'A small-town priest struggles with his faith.',
#   'Votes': '26,080',
#   'Gross': 0},
#  {'Rank': '973.',
#   'Title': 'Zelig',
#   'Year': '(1983)',
#   'PG': 'PG',
#   'Runtime': '79 min',
#   'Genre': 'Comedy',
#   'IMDB_Rating': '7.7',
#   'Metascore': '0',
#   'Director': ['Woody Allen'],
#   'Stars': ['Woody Allen', 'Mia Farrow', 'Patrick Horgan', 'John Buckwalter'],
#   'Description': '"Documentary" about a man who can look and act like whoever he\'s around, and meets various famous people.',
#   'Votes': '43,140',
#   'Gross': '$11.80M'},
#  {'Rank': '974.',
#   'Title': 'Paan Singh Tomar',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '135 min',
#   'Genre': 'Action, Biography, Crime',
#   'IMDB_Rating': '8.2',
#   'Metascore': '0',
#   'Director': ['Tigmanshu Dhulia'],
#   'Stars': ['Irrfan Khan', 'Mahie Gill', 'Rajesh Abhay', 'Hemendra Dandotiya'],
#   'Description': 'The story of Paan Singh Tomar, an Indian athlete and seven-time national steeplechase champion who becomes one of the most feared dacoits in Chambal Valley after his retirement.',
#   'Votes': '37,140',
#   'Gross': '$0.04M'},
#  {'Rank': '975.',
#   'Title': 'Rangasthalam 1985',
#   'Year': '(2018)',
#   'PG': 'Not Rated',
#   'Runtime': '170 min',
#   'Genre': 'Action, Drama',
#   'IMDB_Rating': '8.2',
#   'Metascore': '0',
#   'Director': ['Sukumar'],
#   'Stars': ['Ram Charan', 'Samantha Ruth Prabhu', 'Aadhi', 'Jagapathi Babu'],
#   'Description': "Chitti Babu begins to suspect his elder brother's life is in danger after they team up to lock horns with their village president and overthrow his unlawful 30 year old regime.",
#   'Votes': '26,293',
#   'Gross': '$3.51M'},
#  {'Rank': '976.',
#   'Title': 'Asuran',
#   'Year': '(2019)',
#   'PG': 'Not Rated',
#   'Runtime': '141 min',
#   'Genre': 'Action, Drama',
#   'IMDB_Rating': '8.4',
#   'Metascore': '0',
#   'Director': ['Vetrimaaran'],
#   'Stars': ['Dhanush', 'Manju Warrier', 'Prakash Raj', 'Pasupathy'],
#   'Description': 'The teenage son of a farmer from an underprivileged caste kills a rich, upper caste landlord. How the pacifist farmer saves his hot-blooded son is the rest of the story.',
#   'Votes': '31,441',
#   'Gross': 0},
#  {'Rank': '977.',
#   'Title': 'Carry On, Munna Bhai',
#   'Year': '(2006)',
#   'PG': 'Not Rated',
#   'Runtime': '144 min',
#   'Genre': 'Comedy, Drama, Romance',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Rajkumar Hirani'],
#   'Stars': ['Sanjay Dutt', 'Arshad Warsi', 'Vidya Balan', 'Boman Irani'],
#   'Description': 'Munna Bhai embarks on a journey with Mahatma Gandhi in order to fight against a corrupt property dealer.',
#   'Votes': '48,288',
#   'Gross': '$2.22M'},
#  {'Rank': '978.',
#   'Title': 'The Edge of Heaven',
#   'Year': '(2007)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '7.7',
#   'Metascore': '85',
#   'Director': ['Fatih Akin'],
#   'Stars': ['Baki Davrak', 'Gürsoy Gemec', 'Cengiz Daner', 'Tuncel Kurtiz'],
#   'Description': "A Turkish man travels to Istanbul to find the daughter of his father's former girlfriend.",
#   'Votes': '32,821',
#   'Gross': '$0.74M'},
#  {'Rank': '979.',
#   'Title': 'Kahaani',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Mystery, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Sujoy Ghosh'],
#   'Stars': ['Vidya Balan',
#    'Parambrata Chattopadhyay',
#    'Indraneil Sengupta',
#    'Nawazuddin Siddiqui'],
#   'Description': "A pregnant woman's search for her missing husband takes her from London to Kolkata, but everyone she questions denies having ever met him.",
#   'Votes': '64,190',
#   'Gross': '$1.04M'},
#  {'Rank': '980.',
#   'Title': 'Drishyam',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '160 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.3',
#   'Metascore': '0',
#   'Director': ['Jeethu Joseph'],
#   'Stars': ['Mohanlal', 'Meena', 'Asha Sharath', 'Ansiba'],
#   'Description': 'A man goes to extreme lengths to save his family from punishment after the family commits an accidental crime.',
#   'Votes': '42,776',
#   'Gross': 0},
#  {'Rank': '981.',
#   'Title': 'Hindi Medium',
#   'Year': '(2017)',
#   'PG': 'Not Rated',
#   'Runtime': '132 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.8',
#   'Metascore': '0',
#   'Director': ['Saket Chaudhary'],
#   'Stars': ['Irrfan Khan', 'Saba Qamar', 'Dishita Sehgal', 'Deepak Dobriyal'],
#   'Description': 'A couple from Chandni Chowk aspire to give their daughter the best education and thus be a part of and accepted by the elite of Delhi.',
#   'Votes': '30,736',
#   'Gross': 0},
#  {'Rank': '982.',
#   'Title': 'Hera Pheri',
#   'Year': '(2000)',
#   'PG': 'Not Rated',
#   'Runtime': '156 min',
#   'Genre': 'Action, Comedy, Crime',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Priyadarshan'],
#   'Stars': ['Akshay Kumar', 'Suniel Shetty', 'Paresh Rawal', 'Tabu'],
#   'Description': 'Three unemployed men look for answers to all their money problems - but when their opportunity arrives, will they know what to do with it?',
#   'Votes': '69,721',
#   'Gross': 0},
#  {'Rank': '983.',
#   'Title': 'The Bandit',
#   'Year': '(1996)',
#   'PG': 'Not Rated',
#   'Runtime': '128 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Yavuz Turgul'],
#   'Stars': ['Sener Sen', 'Ugur Yücel', 'Sermin Hürmeriç', 'Yesim Salkim'],
#   'Description': 'Baran the Bandit, released from prison after 35 years, searches for vengeance and his lover.',
#   'Votes': '71,008',
#   'Gross': 0},
#  {'Rank': '984.',
#   'Title': 'The Circus',
#   'Year': '(1928)',
#   'PG': 'Passed',
#   'Runtime': '72 min',
#   'Genre': 'Comedy, Family, Romance',
#   'IMDB_Rating': '8.1',
#   'Metascore': '90',
#   'Director': ['Charles Chaplin'],
#   'Stars': ['Charles Chaplin',
#    'Merna Kennedy',
#    'Al Ernest Garcia',
#    'Harry Crocker'],
#   'Description': 'The Tramp finds work and the girl of his dreams at a circus.',
#   'Votes': '34,981',
#   'Gross': 0},
#  {'Rank': '985.',
#   'Title': 'Bhaag Milkha Bhaag',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '186 min',
#   'Genre': 'Biography, Drama, Sport',
#   'IMDB_Rating': '8.2',
#   'Metascore': '0',
#   'Director': ['Rakeysh Omprakash Mehra'],
#   'Stars': ['Farhan Akhtar', 'Japtej Singh', 'Divya Dutta', 'Pawan Malhotra'],
#   'Description': 'The truth behind the ascension of Milkha Singh, who was scarred by of the India-Pakistan partition.',
#   'Votes': '70,028',
#   'Gross': '$1.63M'},
#  {'Rank': '986.',
#   'Title': 'Udaan',
#   'Year': '(2010)',
#   'PG': 'Not Rated',
#   'Runtime': '134 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Vikramaditya Motwane'],
#   'Stars': ['Rajat Barmecha', 'Ronit Roy', 'Manjot Singh', 'Ram Kapoor'],
#   'Description': 'Expelled from his school, a 16-year old boy returns home to his abusive and oppressive father.',
#   'Votes': '45,993',
#   'Gross': '$0.01M'},
#  {'Rank': '987.',
#   'Title': 'OMG: Oh My God!',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '125 min',
#   'Genre': 'Comedy, Drama, Fantasy',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Umesh Shukla'],
#   'Stars': ['Paresh Rawal',
#    'Akshay Kumar',
#    'Mithun Chakraborty',
#    'Mahesh Manjrekar'],
#   'Description': 'A shopkeeper takes God to court when his shop is destroyed by an earthquake.',
#   'Votes': '60,962',
#   'Gross': '$0.92M'},
#  {'Rank': '988.',
#   'Title': 'Black',
#   'Year': '(2005)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Drama',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Sanjay Leela Bhansali'],
#   'Stars': ['Amitabh Bachchan',
#    'Rani Mukerji',
#    'Shernaz Patel',
#    'Ayesha Kapur'],
#   'Description': "The cathartic tale of a young woman who can't see, hear, or speak, and the teacher who brings a ray of light into her dark world.",
#   'Votes': '35,530',
#   'Gross': '$0.73M'},
#  {'Rank': '989.',
#   'Title': 'Drishyam 2',
#   'Year': '(2021)',
#   'PG': 'Not Rated',
#   'Runtime': '152 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.4',
#   'Metascore': '0',
#   'Director': ['Jeethu Joseph'],
#   'Stars': ['Mohanlal', 'Meena', 'Ansiba', 'Esther Anil'],
#   'Description': 'A gripping tale of an investigation and a family which is threatened by it. Will Georgekutty be able to protect his family this time?',
#   'Votes': '39,211',
#   'Gross': 0},
#  {'Rank': '990.',
#   'Title': "Everything's Gonna Be Great",
#   'Year': '(1998)',
#   'PG': 'Not Rated',
#   'Runtime': '107 min',
#   'Genre': 'Comedy, Drama, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Ömer Vargi'],
#   'Stars': ['Cem Yilmaz', 'Mazhar Alanson', 'Ceyda Düvenci', 'Selim Nasit'],
#   'Description': "When Altan swipes prescription drugs from his brother Nuri's pharmacy, they soon find themselves on a dangerous but funny road trip to get rid of the stuff and escape the mafiosi Altan ...                See full summary\xa0»",
#   'Votes': '26,403',
#   'Gross': 0},
#  {'Rank': '991.',
#   'Title': 'Special 26',
#   'Year': '(2013)',
#   'PG': 'Not Rated',
#   'Runtime': '144 min',
#   'Genre': 'Crime, Drama, Thriller',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Neeraj Pandey'],
#   'Stars': ['Akshay Kumar', 'Anupam Kher', 'Manoj Bajpayee', 'Jimmy Shergill'],
#   'Description': 'A gang of con-men rob prominent rich businessmen and politicians by posing as C.B.I and income tax officers.',
#   'Votes': '57,636',
#   'Gross': '$1.08M'},
#  {'Rank': '992.',
#   'Title': 'The Breath',
#   'Year': '(2009)',
#   'PG': 'Not Rated',
#   'Runtime': '128 min',
#   'Genre': 'Action, Drama, Thriller',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Levent Semerci'],
#   'Stars': ['Mete Horozoglu', 'Ilker Kizmaz', 'Birce Akalay', 'Ibrahim Akoz'],
#   'Description': 'Story of 40-man Turkish task force who must defend a relay station.',
#   'Votes': '34,480',
#   'Gross': 0},
#  {'Rank': '993.',
#   'Title': 'Andaz Apna Apna',
#   'Year': '(1994)',
#   'PG': 'Not Rated',
#   'Runtime': '160 min',
#   'Genre': 'Action, Comedy, Romance',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Rajkumar Santoshi'],
#   'Stars': ['Aamir Khan', 'Salman Khan', 'Raveena Tandon', 'Karisma Kapoor'],
#   'Description': 'Two slackers competing for the affections of an heiress inadvertently become her protectors from an evil criminal.',
#   'Votes': '54,305',
#   'Gross': 0},
#  {'Rank': '994.',
#   'Title': 'Pad Man',
#   'Year': '(2018)',
#   'PG': 'PG-13',
#   'Runtime': '140 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '7.9',
#   'Metascore': '0',
#   'Director': ['R. Balki'],
#   'Stars': ['Akshay Kumar', 'Radhika Apte', 'Sonam Kapoor', 'Jyoti Subhash'],
#   'Description': 'Upon realizing the extent to which women are affected by their menses, a man sets out to create a sanitary pad machine and to provide inexpensive sanitary pads to the women of rural India.',
#   'Votes': '27,388',
#   'Gross': '$1.66M'},
#  {'Rank': '995.',
#   'Title': 'Baby',
#   'Year': '(I) (2015)',
#   'PG': 'Not Rated',
#   'Runtime': '159 min',
#   'Genre': 'Action, Crime, Thriller',
#   'IMDB_Rating': '7.9',
#   'Metascore': '0',
#   'Director': ['Neeraj Pandey'],
#   'Stars': ['Akshay Kumar',
#    'Danny Denzongpa',
#    'Rana Daggubati',
#    'Taapsee Pannu'],
#   'Description': "An elite counter-intelligence unit learns of a plot, masterminded by a maniacal madman. With the clock ticking, it's up to them to track the terrorists' international tentacles and prevent them from striking at the heart of India.",
#   'Votes': '58,936',
#   'Gross': 0},
#  {'Rank': '996.',
#   'Title': 'Vicky Donor',
#   'Year': '(2012)',
#   'PG': 'Not Rated',
#   'Runtime': '126 min',
#   'Genre': 'Comedy, Romance',
#   'IMDB_Rating': '7.8',
#   'Metascore': '0',
#   'Director': ['Shoojit Sircar'],
#   'Stars': ['Ayushmann Khurrana',
#    'Yami Gautam',
#    'Annu Kapoor',
#    'Dolly Ahluwalia'],
#   'Description': 'A man is brought in by an infertility doctor to supply him with his sperm, where he becomes the biggest sperm donor for his clinic.',
#   'Votes': '44,440',
#   'Gross': '$0.17M'},
#  {'Rank': '997.',
#   'Title': 'Vizontele',
#   'Year': '(2001)',
#   'PG': 'Not Rated',
#   'Runtime': '110 min',
#   'Genre': 'Comedy, Drama',
#   'IMDB_Rating': '8.0',
#   'Metascore': '0',
#   'Director': ['Yilmaz Erdogan', 'Ömer Faruk Sorak'],
#   'Stars': ['Yilmaz Erdogan', 'Demet Akbag', 'Altan Erkekli', 'Cem Yilmaz'],
#   'Description': 'Lives of residents in a small, Anatolian village change when television is introduced to them.',
#   'Votes': '37,770',
#   'Gross': 0},
#  {'Rank': '998.',
#   'Title': 'Sarfarosh',
#   'Year': '(1999)',
#   'PG': 'Not Rated',
#   'Runtime': '174 min',
#   'Genre': 'Action, Drama, Thriller',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['John Mathew Matthan'],
#   'Stars': ['Ali Khan',
#    'Akhilendra Mishra',
#    'Makrand Deshpande',
#    'Rajesh Joshi'],
#   'Description': 'After his brother is killed and father severely injured by terrorists, a young med student quits his studies to join the Indian Police Service to wipe out the terrorists.',
#   'Votes': '26,295',
#   'Gross': 0},
#  {'Rank': '999.',
#   'Title': 'Airlift',
#   'Year': '(2016)',
#   'PG': 'Not Rated',
#   'Runtime': '130 min',
#   'Genre': 'Action, Drama, History',
#   'IMDB_Rating': '7.9',
#   'Metascore': '0',
#   'Director': ['Raja Menon'],
#   'Stars': ['Akshay Kumar', 'Nimrat Kaur', 'Kumud Mishra', 'Prakash Belawadi'],
#   'Description': 'When Iraq invades Kuwait in August 1990, a callous Indian businessman becomes the spokesperson for more than 170,000 stranded countrymen.',
#   'Votes': '57,938',
#   'Gross': 0},
#  {'Rank': '1,000.',
#   'Title': 'Anand',
#   'Year': '(1971)',
#   'PG': 'Not Rated',
#   'Runtime': '122 min',
#   'Genre': 'Drama, Musical',
#   'IMDB_Rating': '8.1',
#   'Metascore': '0',
#   'Director': ['Hrishikesh Mukherjee'],
#   'Stars': ['Rajesh Khanna',
#    'Amitabh Bachchan',
#    'Sumita Sanyal',
#    'Ramesh Deo'],
#   'Description': 'The story of a terminally ill man who wishes to live life to the fullest before the inevitable occurs, as told by his best friend.',
#   'Votes': '34,528',
#   'Gross': 0}]

# %% [markdown]
# ## 2. Building a DataFrame With pandas
# Put the data into data frame with Pandas

# %%
df = pd.DataFrame(data, columns=['Rank', 'Title', 'Year', 'PG','Runtime','Genre','IMDB_Rating',
                                 'Metascore','Director','Stars','Description','Votes','Gross'])
df
# Out:
#        Rank                                          Title    Year         PG  \
# 0        1.            Spider-Man: Across the Spider-Verse  (2023)         PG
# 1        2.                                        Titanic  (1997)      PG-13
# 2        3.                       Avatar: The Way of Water  (2022)      PG-13
# 3        4.                           John Wick: Chapter 4  (2023)          R
# 4        5.  Indiana Jones and the Raiders of the Lost Ark  (1981)         PG
# ..      ...                                            ...     ...        ...
# 995    996.                                    Vicky Donor  (2012)  Not Rated
# 996    997.                                      Vizontele  (2001)  Not Rated
# 997    998.                                      Sarfarosh  (1999)  Not Rated
# 998    999.                                        Airlift  (2016)  Not Rated
# 999  1,000.                                          Anand  (1971)  Not Rated
#
#      Runtime                         Genre IMDB_Rating Metascore  \
# 0    140 min  Animation, Action, Adventure         8.9        86
# 1    194 min                Drama, Romance         7.9        75
# 2    192 min    Action, Adventure, Fantasy         7.6        67
# 3    169 min       Action, Crime, Thriller         7.9        78
# 4    115 min             Action, Adventure         8.4        85
# ..       ...                           ...         ...       ...
# 995  126 min               Comedy, Romance         7.8         0
# 996  110 min                 Comedy, Drama         8.0         0
# 997  174 min       Action, Drama, Thriller         8.1         0
# 998  130 min        Action, Drama, History         7.9         0
# 999  122 min                Drama, Musical         8.1         0
#
#                                               Director  \
# 0    [Joaquim Dos Santos, Kemp Powers, Justin K. Th...
# 1                                      [James Cameron]
# 2                                      [James Cameron]
# 3                                     [Chad Stahelski]
# 4                                   [Steven Spielberg]
# ..                                                 ...
# 995                                   [Shoojit Sircar]
# 996                 [Yilmaz Erdogan, Ömer Faruk Sorak]
# 997                              [John Mathew Matthan]
# 998                                       [Raja Menon]
# 999                             [Hrishikesh Mukherjee]
#
#                                                  Stars  \
# 0    [Shameik Moore, Hailee Steinfeld, Brian Tyree ...
# 1    [Leonardo DiCaprio, Kate Winslet, Billy Zane, ...
# 2    [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3    [Keanu Reeves, Laurence Fishburne, George Geor...
# 4    [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# ..                                                 ...
# 995  [Ayushmann Khurrana, Yami Gautam, Annu Kapoor,...
# 996  [Yilmaz Erdogan, Demet Akbag, Altan Erkekli, C...
# 997  [Ali Khan, Akhilendra Mishra, Makrand Deshpand...
# 998  [Akshay Kumar, Nimrat Kaur, Kumud Mishra, Prak...
# 999  [Rajesh Khanna, Amitabh Bachchan, Sumita Sanya...
#
#                                            Description      Votes     Gross
# 0    Miles Morales catapults across the Multiverse,...    171,148       #12
# 1    A seventeen-year-old aristocrat falls in love ...  1,228,477  $659.33M
# 2    Jake Sully lives with his newfound family form...    425,970  $659.68M
# 3    John Wick uncovers a path to defeating The Hig...    232,446         0
# 4    In 1936, archaeologist and adventurer Indiana ...    998,751  $248.16M
# ..                                                 ...        ...       ...
# 995  A man is brought in by an infertility doctor t...     44,440    $0.17M
# 996  Lives of residents in a small, Anatolian villa...     37,770         0
# 997  After his brother is killed and father severel...     26,295         0
# 998  When Iraq invades Kuwait in August 1990, a cal...     57,938         0
# 999  The story of a terminally ill man who wishes t...     34,528         0
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# Data cleaning - remove the '()' from year

# %%
df['Year'] = df['Year'].str.replace(r"\(|\)", "", regex=True)
df
# Out:
#        Rank                                          Title  Year         PG  \
# 0        1.            Spider-Man: Across the Spider-Verse  2023         PG
# 1        2.                                        Titanic  1997      PG-13
# 2        3.                       Avatar: The Way of Water  2022      PG-13
# 3        4.                           John Wick: Chapter 4  2023          R
# 4        5.  Indiana Jones and the Raiders of the Lost Ark  1981         PG
# ..      ...                                            ...   ...        ...
# 995    996.                                    Vicky Donor  2012  Not Rated
# 996    997.                                      Vizontele  2001  Not Rated
# 997    998.                                      Sarfarosh  1999  Not Rated
# 998    999.                                        Airlift  2016  Not Rated
# 999  1,000.                                          Anand  1971  Not Rated
#
#      Runtime                         Genre IMDB_Rating Metascore  \
# 0    140 min  Animation, Action, Adventure         8.9        86
# 1    194 min                Drama, Romance         7.9        75
# 2    192 min    Action, Adventure, Fantasy         7.6        67
# 3    169 min       Action, Crime, Thriller         7.9        78
# 4    115 min             Action, Adventure         8.4        85
# ..       ...                           ...         ...       ...
# 995  126 min               Comedy, Romance         7.8         0
# 996  110 min                 Comedy, Drama         8.0         0
# 997  174 min       Action, Drama, Thriller         8.1         0
# 998  130 min        Action, Drama, History         7.9         0
# 999  122 min                Drama, Musical         8.1         0
#
#                                               Director  \
# 0    [Joaquim Dos Santos, Kemp Powers, Justin K. Th...
# 1                                      [James Cameron]
# 2                                      [James Cameron]
# 3                                     [Chad Stahelski]
# 4                                   [Steven Spielberg]
# ..                                                 ...
# 995                                   [Shoojit Sircar]
# 996                 [Yilmaz Erdogan, Ömer Faruk Sorak]
# 997                              [John Mathew Matthan]
# 998                                       [Raja Menon]
# 999                             [Hrishikesh Mukherjee]
#
#                                                  Stars  \
# 0    [Shameik Moore, Hailee Steinfeld, Brian Tyree ...
# 1    [Leonardo DiCaprio, Kate Winslet, Billy Zane, ...
# 2    [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3    [Keanu Reeves, Laurence Fishburne, George Geor...
# 4    [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# ..                                                 ...
# 995  [Ayushmann Khurrana, Yami Gautam, Annu Kapoor,...
# 996  [Yilmaz Erdogan, Demet Akbag, Altan Erkekli, C...
# 997  [Ali Khan, Akhilendra Mishra, Makrand Deshpand...
# 998  [Akshay Kumar, Nimrat Kaur, Kumud Mishra, Prak...
# 999  [Rajesh Khanna, Amitabh Bachchan, Sumita Sanya...
#
#                                            Description      Votes     Gross
# 0    Miles Morales catapults across the Multiverse,...    171,148       #12
# 1    A seventeen-year-old aristocrat falls in love ...  1,228,477  $659.33M
# 2    Jake Sully lives with his newfound family form...    425,970  $659.68M
# 3    John Wick uncovers a path to defeating The Hig...    232,446         0
# 4    In 1936, archaeologist and adventurer Indiana ...    998,751  $248.16M
# ..                                                 ...        ...       ...
# 995  A man is brought in by an infertility doctor t...     44,440    $0.17M
# 996  Lives of residents in a small, Anatolian villa...     37,770         0
# 997  After his brother is killed and father severel...     26,295         0
# 998  When Iraq invades Kuwait in August 1990, a cal...     57,938         0
# 999  The story of a terminally ill man who wishes t...     34,528         0
#
# [1000 rows x 13 columns]

# %% [markdown]
# Data cleaning - remove the min from the timemin value

# %%
df['Runtime'] = df['Runtime'].str.replace(' min', '')

df
# Out:
#        Rank                                          Title  Year         PG  \
# 0        1.            Spider-Man: Across the Spider-Verse  2023         PG
# 1        2.                                        Titanic  1997      PG-13
# 2        3.                       Avatar: The Way of Water  2022      PG-13
# 3        4.                           John Wick: Chapter 4  2023          R
# 4        5.  Indiana Jones and the Raiders of the Lost Ark  1981         PG
# ..      ...                                            ...   ...        ...
# 995    996.                                    Vicky Donor  2012  Not Rated
# 996    997.                                      Vizontele  2001  Not Rated
# 997    998.                                      Sarfarosh  1999  Not Rated
# 998    999.                                        Airlift  2016  Not Rated
# 999  1,000.                                          Anand  1971  Not Rated
#
#     Runtime                         Genre IMDB_Rating Metascore  \
# 0       140  Animation, Action, Adventure         8.9        86
# 1       194                Drama, Romance         7.9        75
# 2       192    Action, Adventure, Fantasy         7.6        67
# 3       169       Action, Crime, Thriller         7.9        78
# 4       115             Action, Adventure         8.4        85
# ..      ...                           ...         ...       ...
# 995     126               Comedy, Romance         7.8         0
# 996     110                 Comedy, Drama         8.0         0
# 997     174       Action, Drama, Thriller         8.1         0
# 998     130        Action, Drama, History         7.9         0
# 999     122                Drama, Musical         8.1         0
#
#                                               Director  \
# 0    [Joaquim Dos Santos, Kemp Powers, Justin K. Th...
# 1                                      [James Cameron]
# 2                                      [James Cameron]
# 3                                     [Chad Stahelski]
# 4                                   [Steven Spielberg]
# ..                                                 ...
# 995                                   [Shoojit Sircar]
# 996                 [Yilmaz Erdogan, Ömer Faruk Sorak]
# 997                              [John Mathew Matthan]
# 998                                       [Raja Menon]
# 999                             [Hrishikesh Mukherjee]
#
#                                                  Stars  \
# 0    [Shameik Moore, Hailee Steinfeld, Brian Tyree ...
# 1    [Leonardo DiCaprio, Kate Winslet, Billy Zane, ...
# 2    [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3    [Keanu Reeves, Laurence Fishburne, George Geor...
# 4    [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# ..                                                 ...
# 995  [Ayushmann Khurrana, Yami Gautam, Annu Kapoor,...
# 996  [Yilmaz Erdogan, Demet Akbag, Altan Erkekli, C...
# 997  [Ali Khan, Akhilendra Mishra, Makrand Deshpand...
# 998  [Akshay Kumar, Nimrat Kaur, Kumud Mishra, Prak...
# 999  [Rajesh Khanna, Amitabh Bachchan, Sumita Sanya...
#
#                                            Description      Votes     Gross
# 0    Miles Morales catapults across the Multiverse,...    171,148       #12
# 1    A seventeen-year-old aristocrat falls in love ...  1,228,477  $659.33M
# 2    Jake Sully lives with his newfound family form...    425,970  $659.68M
# 3    John Wick uncovers a path to defeating The Hig...    232,446         0
# 4    In 1936, archaeologist and adventurer Indiana ...    998,751  $248.16M
# ..                                                 ...        ...       ...
# 995  A man is brought in by an infertility doctor t...     44,440    $0.17M
# 996  Lives of residents in a small, Anatolian villa...     37,770         0
# 997  After his brother is killed and father severel...     26,295         0
# 998  When Iraq invades Kuwait in August 1990, a cal...     57,938         0
# 999  The story of a terminally ill man who wishes t...     34,528         0
#
# [1000 rows x 13 columns]

# %% [markdown]
# Data cleaning - remove the $ and M from the data value

# %%
df['Gross'] = df['Gross'].str.replace('$', '', regex=False).str.replace('M', '', regex=False)
df
# Out:
#        Rank                                          Title  Year         PG  \
# 0        1.            Spider-Man: Across the Spider-Verse  2023         PG
# 1        2.                                        Titanic  1997      PG-13
# 2        3.                       Avatar: The Way of Water  2022      PG-13
# 3        4.                           John Wick: Chapter 4  2023          R
# 4        5.  Indiana Jones and the Raiders of the Lost Ark  1981         PG
# ..      ...                                            ...   ...        ...
# 995    996.                                    Vicky Donor  2012  Not Rated
# 996    997.                                      Vizontele  2001  Not Rated
# 997    998.                                      Sarfarosh  1999  Not Rated
# 998    999.                                        Airlift  2016  Not Rated
# 999  1,000.                                          Anand  1971  Not Rated
#
#     Runtime                         Genre IMDB_Rating Metascore  \
# 0       140  Animation, Action, Adventure         8.9        86
# 1       194                Drama, Romance         7.9        75
# 2       192    Action, Adventure, Fantasy         7.6        67
# 3       169       Action, Crime, Thriller         7.9        78
# 4       115             Action, Adventure         8.4        85
# ..      ...                           ...         ...       ...
# 995     126               Comedy, Romance         7.8         0
# 996     110                 Comedy, Drama         8.0         0
# 997     174       Action, Drama, Thriller         8.1         0
# 998     130        Action, Drama, History         7.9         0
# 999     122                Drama, Musical         8.1         0
#
#                                               Director  \
# 0    [Joaquim Dos Santos, Kemp Powers, Justin K. Th...
# 1                                      [James Cameron]
# 2                                      [James Cameron]
# 3                                     [Chad Stahelski]
# 4                                   [Steven Spielberg]
# ..                                                 ...
# 995                                   [Shoojit Sircar]
# 996                 [Yilmaz Erdogan, Ömer Faruk Sorak]
# 997                              [John Mathew Matthan]
# 998                                       [Raja Menon]
# 999                             [Hrishikesh Mukherjee]
#
#                                                  Stars  \
# 0    [Shameik Moore, Hailee Steinfeld, Brian Tyree ...
# 1    [Leonardo DiCaprio, Kate Winslet, Billy Zane, ...
# 2    [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3    [Keanu Reeves, Laurence Fishburne, George Geor...
# 4    [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# ..                                                 ...
# 995  [Ayushmann Khurrana, Yami Gautam, Annu Kapoor,...
# 996  [Yilmaz Erdogan, Demet Akbag, Altan Erkekli, C...
# 997  [Ali Khan, Akhilendra Mishra, Makrand Deshpand...
# 998  [Akshay Kumar, Nimrat Kaur, Kumud Mishra, Prak...
# 999  [Rajesh Khanna, Amitabh Bachchan, Sumita Sanya...
#
#                                            Description      Votes   Gross
# 0    Miles Morales catapults across the Multiverse,...    171,148     #12
# 1    A seventeen-year-old aristocrat falls in love ...  1,228,477  659.33
# 2    Jake Sully lives with his newfound family form...    425,970  659.68
# 3    John Wick uncovers a path to defeating The Hig...    232,446     NaN
# 4    In 1936, archaeologist and adventurer Indiana ...    998,751  248.16
# ..                                                 ...        ...     ...
# 995  A man is brought in by an infertility doctor t...     44,440    0.17
# 996  Lives of residents in a small, Anatolian villa...     37,770     NaN
# 997  After his brother is killed and father severel...     26,295     NaN
# 998  When Iraq invades Kuwait in August 1990, a cal...     57,938     NaN
# 999  The story of a terminally ill man who wishes t...     34,528     NaN
#
# [1000 rows x 13 columns]

# %% [markdown]
# Data cleaning - clear the ',' from the votes value

# %%
df['Votes'] = df['Votes'].str.replace(',', '')
df
# Out:
#        Rank                                          Title  Year         PG  \
# 0        1.            Spider-Man: Across the Spider-Verse  2023         PG
# 1        2.                                        Titanic  1997      PG-13
# 2        3.                       Avatar: The Way of Water  2022      PG-13
# 3        4.                           John Wick: Chapter 4  2023          R
# 4        5.  Indiana Jones and the Raiders of the Lost Ark  1981         PG
# ..      ...                                            ...   ...        ...
# 995    996.                                    Vicky Donor  2012  Not Rated
# 996    997.                                      Vizontele  2001  Not Rated
# 997    998.                                      Sarfarosh  1999  Not Rated
# 998    999.                                        Airlift  2016  Not Rated
# 999  1,000.                                          Anand  1971  Not Rated
#
#     Runtime                         Genre IMDB_Rating Metascore  \
# 0       140  Animation, Action, Adventure         8.9        86
# 1       194                Drama, Romance         7.9        75
# 2       192    Action, Adventure, Fantasy         7.6        67
# 3       169       Action, Crime, Thriller         7.9        78
# 4       115             Action, Adventure         8.4        85
# ..      ...                           ...         ...       ...
# 995     126               Comedy, Romance         7.8         0
# 996     110                 Comedy, Drama         8.0         0
# 997     174       Action, Drama, Thriller         8.1         0
# 998     130        Action, Drama, History         7.9         0
# 999     122                Drama, Musical         8.1         0
#
#                                               Director  \
# 0    [Joaquim Dos Santos, Kemp Powers, Justin K. Th...
# 1                                      [James Cameron]
# 2                                      [James Cameron]
# 3                                     [Chad Stahelski]
# 4                                   [Steven Spielberg]
# ..                                                 ...
# 995                                   [Shoojit Sircar]
# 996                 [Yilmaz Erdogan, Ömer Faruk Sorak]
# 997                              [John Mathew Matthan]
# 998                                       [Raja Menon]
# 999                             [Hrishikesh Mukherjee]
#
#                                                  Stars  \
# 0    [Shameik Moore, Hailee Steinfeld, Brian Tyree ...
# 1    [Leonardo DiCaprio, Kate Winslet, Billy Zane, ...
# 2    [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3    [Keanu Reeves, Laurence Fishburne, George Geor...
# 4    [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# ..                                                 ...
# 995  [Ayushmann Khurrana, Yami Gautam, Annu Kapoor,...
# 996  [Yilmaz Erdogan, Demet Akbag, Altan Erkekli, C...
# 997  [Ali Khan, Akhilendra Mishra, Makrand Deshpand...
# 998  [Akshay Kumar, Nimrat Kaur, Kumud Mishra, Prak...
# 999  [Rajesh Khanna, Amitabh Bachchan, Sumita Sanya...
#
#                                            Description    Votes   Gross
# 0    Miles Morales catapults across the Multiverse,...   171148     #12
# 1    A seventeen-year-old aristocrat falls in love ...  1228477  659.33
# 2    Jake Sully lives with his newfound family form...   425970  659.68
# 3    John Wick uncovers a path to defeating The Hig...   232446     NaN
# 4    In 1936, archaeologist and adventurer Indiana ...   998751  248.16
# ..                                                 ...      ...     ...
# 995  A man is brought in by an infertility doctor t...    44440    0.17
# 996  Lives of residents in a small, Anatolian villa...    37770     NaN
# 997  After his brother is killed and father severel...    26295     NaN
# 998  When Iraq invades Kuwait in August 1990, a cal...    57938     NaN
# 999  The story of a terminally ill man who wishes t...    34528     NaN
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## 4. Display Cleaned and Converted Code in Pandas

# %%
print(df)
# Out:
#        Rank                                          Title  Year         PG  \
# 0        1.            Spider-Man: Across the Spider-Verse  2023         PG
# 1        2.                                        Titanic  1997      PG-13
# 2        3.                       Avatar: The Way of Water  2022      PG-13
# 3        4.                           John Wick: Chapter 4  2023          R
# 4        5.  Indiana Jones and the Raiders of the Lost Ark  1981         PG
# ..      ...                                            ...   ...        ...
# 995    996.                                    Vicky Donor  2012  Not Rated
# 996    997.                                      Vizontele  2001  Not Rated
# 997    998.                                      Sarfarosh  1999  Not Rated
# 998    999.                                        Airlift  2016  Not Rated
# 999  1,000.                                          Anand  1971  Not Rated
#
#     Runtime                         Genre IMDB_Rating Metascore  \
# 0       140  Animation, Action, Adventure         8.9        86
# 1       194                Drama, Romance         7.9        75
# 2       192    Action, Adventure, Fantasy         7.6        67
# 3       169       Action, Crime, Thriller         7.9        78
# 4       115             Action, Adventure         8.4        85
# ..      ...                           ...         ...       ...
# 995     126               Comedy, Romance         7.8         0
# 996     110                 Comedy, Drama         8.0         0
# 997     174       Action, Drama, Thriller         8.1         0
# 998     130        Action, Drama, History         7.9         0
# 999     122                Drama, Musical         8.1         0
#
#                                               Director  \
# 0    [Joaquim Dos Santos, Kemp Powers, Justin K. Th...
# 1                                      [James Cameron]
# 2                                      [James Cameron]
# 3                                     [Chad Stahelski]
# 4                                   [Steven Spielberg]
# ..                                                 ...
# 995                                   [Shoojit Sircar]
# 996                 [Yilmaz Erdogan, Ömer Faruk Sorak]
# 997                              [John Mathew Matthan]
# 998                                       [Raja Menon]
# 999                             [Hrishikesh Mukherjee]
#
#                                                  Stars  \
# 0    [Shameik Moore, Hailee Steinfeld, Brian Tyree ...
# 1    [Leonardo DiCaprio, Kate Winslet, Billy Zane, ...
# 2    [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 3    [Keanu Reeves, Laurence Fishburne, George Geor...
# 4    [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# ..                                                 ...
# 995  [Ayushmann Khurrana, Yami Gautam, Annu Kapoor,...
# 996  [Yilmaz Erdogan, Demet Akbag, Altan Erkekli, C...
# 997  [Ali Khan, Akhilendra Mishra, Makrand Deshpand...
# 998  [Akshay Kumar, Nimrat Kaur, Kumud Mishra, Prak...
# 999  [Rajesh Khanna, Amitabh Bachchan, Sumita Sanya...
#
#                                            Description    Votes   Gross
# 0    Miles Morales catapults across the Multiverse,...   171148     #12
# 1    A seventeen-year-old aristocrat falls in love ...  1228477  659.33
# 2    Jake Sully lives with his newfound family form...   425970  659.68
# 3    John Wick uncovers a path to defeating The Hig...   232446     NaN
# 4    In 1936, archaeologist and adventurer Indiana ...   998751  248.16
# ..                                                 ...      ...     ...
# 995  A man is brought in by an infertility doctor t...    44440    0.17
# 996  Lives of residents in a small, Anatolian villa...    37770     NaN
# 997  After his brother is killed and father severel...    26295     NaN
# 998  When Iraq invades Kuwait in August 1990, a cal...    57938     NaN
# 999  The story of a terminally ill man who wishes t...    34528     NaN
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## 5. Saving Your Data to a CSV

# %%
df.to_csv('imdb.csv',index=False)

# %% [markdown]
# ## 6. Conclusion
# What have you leanrt from this practice?

# %%
# First question is the hardest part when scrapping the data from the web and put it to seperate columns
