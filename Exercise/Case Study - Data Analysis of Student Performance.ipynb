# %% [markdown]
# <img src="https://i.imgur.com/FoKB5Z5.png" align="left" width="300" height="250" title="source: imgur.com" /></a>

# %% [markdown]
# ## Program Code: J620-002-4:2020
#
# ## Program Name: FRONT-END SOFTWARE DEVELOPMENT
#
# ## Title :  Case Study - Data Analysis of Student Performance
#
# #### Name:  Ooi Caaron
#
# #### IC Number: 990701-07-5837
#
# #### Date : 7/7/23
#
# #### Introduction :
#
#
#
# #### Conclusion : Still need to practice more and do revision

# %% [markdown]
# **Guideline EDA
# link: https://medium.com/dataseries/an-eda-checklist-800beeaee555**

# %% [markdown]
# **Sample Exercise:**
#
# High Student students academic performance
#
# I'll do the dataset in Excel
#
#
#
# **Randomizers in Excel (dont shoot me)**
#
# I like to "visualize my simulated data"
#
# =RANDBETWEEN(0,100)
#
# =CHOOSE(RANDBETWEEN(1,3),"B40","M40","T20")

# %% [markdown]
# **What data is needed?**
#
# Describe the data
#
#     Student demography
#     Subjects taken
#     Trial exam results
#     attendance, contact Hours
#     Final results
#     Others? Sports activities
#
#
# "Correlation is not causation"
#
# Means that just because two things correlate does not necessarily mean that one causes the other. ... Correlations between two things can be caused by a third factor that affects both of them. This sneaky, hidden third wheel is called a confounder.

# %% [markdown]
# **Case Study Exercise**
#
# Plot the Student Results table
#
# Some basic stats
#
# Look for Average, Min, Max

# %% [markdown]
# ## Exploratory Data Analysis (EDA) Check list
#
# - Domain knowledge
#     - What is this dataset about?
# - Check if the data is intuitive
# - Find out how the data was generated
# - Understand the process
#
# ----
# - Select a smaller dataset
#     - depending on the data size, If what to go big bang, make sure enough resources.
# - Explore individual features
# - Explore pairs and groups
#
# ----
#
# - Clean up features
#
# - Selecting features of interest
#
# - Generating derived feature(s)
#
# - Extract , Transform and Load (the whole dataset)
#
# - Sampling the data (in ML)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Import Data from CSV

# %%
df = pd.read_csv('StudentResults.csv')
df
# Out:
#     StudentID      Name  Term IncomeGroup NonsenseData      School Tuisyen  \
# 0           7       Psy     2         B40         xvxc  SK Bestari      No
# 1           8    Edward     2         M40           sf  SK Bestari     Yes
# 2           6   Mei Lin     2         M40          dsf  SK Bestari     Yes
# 3           9  Miyazawa     2         T20           df  SK Bestari      No
# 4           4  Letchumi     2         T20         xvxc  SK Bestari      No
# 5           3     Muthu     2         T20           sf  SK Bestari     Yes
# 6           5  Ah Chong     2         B40          dsf  SK Bestari     Yes
# 7           2      Siti     2         M40           df  SK Bestari     Yes
# 8           1       Ali     2         B40         xvxc  SK Bestari      No
# 9          10   Ah Beng     2         T20           sf  SK Bestari      No
# 10          7       Psy     1         B40          dsf  SK Bestari      No
# 11          8    Edward     1         M40           df  SK Bestari     Yes
# 12          6   Mei Lin     1         M40         xvxc  SK Bestari     Yes
# 13          9  Miyazawa     1         T20           sf  SK Bestari      No
# 14          4  Letchumi     1         T20          dsf  SK Bestari      No
# 15          3     Muthu     1         T20           df  SK Bestari     Yes
# 16          5  Ah Chong     1         B40         xvxc  SK Bestari     Yes
# 17          2      Siti     1         M40           sf  SK Bestari     Yes
# 18          1       Ali     1         B40          dsf  SK Bestari      No
# 19         10   Ah Beng     1         T20           df  SK Bestari      No
#
#     Attendance  BM     BI  Maths  Sejarah  Total
# 0           60  24    NaN     37       16     77
# 1           30  43   28.0     22       34    127
# 2           78   0   20.0     47       63    130
# 3          100  32   94.0     33        1    160
# 4           80  97   52.0     17       11    177
# 5           58  31   65.0      0       82    178
# 6           64  16   84.0      6       94    200
# 7           57  35   68.0     35       72    210
# 8          100  16   89.0     97       97    299
# 9          100  43  100.0     90       92    325
# 10          60  14  -10.0     27        6     37
# 11          30  33   18.0     12       24     87
# 12          78  10   10.0     37       53    110
# 13         100  22   84.0     23       -9    120
# 14          80  87   42.0      7        1    137
# 15          58  21   55.0     10       72    158
# 16          64   6   74.0      4       84    168
# 17          57  25   58.0     25       62    170
# 18         100   6   79.0     87       87    259
# 19         100  33   90.0     80       82    285

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   StudentID     20 non-null     int64
#  1   Name          20 non-null     object
#  2   Term          20 non-null     int64
#  3   IncomeGroup   20 non-null     object
#  4   NonsenseData  20 non-null     object
#  5   School        20 non-null     object
#  6   Tuisyen       20 non-null     object
#  7   Attendance    20 non-null     int64
#  8   BM            20 non-null     int64
#  9   BI            19 non-null     float64
#  10  Maths         20 non-null     int64
#  11  Sejarah       20 non-null     int64
#  12  Total         20 non-null     int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.2+ KB

# %%
df.isnull().sum()
# Out:
# StudentID       0
# Name            0
# Term            0
# IncomeGroup     0
# NonsenseData    0
# School          0
# Tuisyen         0
# Attendance      0
# BM              0
# BI              1
# Maths           0
# Sejarah         0
# Total           0
# dtype: int64

# %% [markdown]
# ## 2. Data Cleaning - Remove Useless Data

# %%
df['BI'] = df['BI'].fillna(0).clip(lower=0)
df.sort_values('StudentID').set_index('StudentID')
# Out:
#                Name  Term IncomeGroup NonsenseData      School Tuisyen  \
# StudentID
# 1               Ali     2         B40         xvxc  SK Bestari      No
# 1               Ali     1         B40          dsf  SK Bestari      No
# 2              Siti     2         M40           df  SK Bestari     Yes
# 2              Siti     1         M40           sf  SK Bestari     Yes
# 3             Muthu     2         T20           sf  SK Bestari     Yes
# 3             Muthu     1         T20           df  SK Bestari     Yes
# 4          Letchumi     2         T20         xvxc  SK Bestari      No
# 4          Letchumi     1         T20          dsf  SK Bestari      No
# 5          Ah Chong     2         B40          dsf  SK Bestari     Yes
# 5          Ah Chong     1         B40         xvxc  SK Bestari     Yes
# 6           Mei Lin     2         M40          dsf  SK Bestari     Yes
# 6           Mei Lin     1         M40         xvxc  SK Bestari     Yes
# 7               Psy     1         B40          dsf  SK Bestari      No
# 7               Psy     2         B40         xvxc  SK Bestari      No
# 8            Edward     2         M40           sf  SK Bestari     Yes
# 8            Edward     1         M40           df  SK Bestari     Yes
# 9          Miyazawa     1         T20           sf  SK Bestari      No
# 9          Miyazawa     2         T20           df  SK Bestari      No
# 10          Ah Beng     2         T20           sf  SK Bestari      No
# 10          Ah Beng     1         T20           df  SK Bestari      No
#
#            Attendance  BM     BI  Maths  Sejarah  Total
# StudentID
# 1                 100  16   89.0     97       97    299
# 1                 100   6   79.0     87       87    259
# 2                  57  35   68.0     35       72    210
# 2                  57  25   58.0     25       62    170
# 3                  58  31   65.0      0       82    178
# 3                  58  21   55.0     10       72    158
# 4                  80  97   52.0     17       11    177
# 4                  80  87   42.0      7        1    137
# 5                  64  16   84.0      6       94    200
# 5                  64   6   74.0      4       84    168
# 6                  78   0   20.0     47       63    130
# 6                  78  10   10.0     37       53    110
# 7                  60  14    0.0     27        6     37
# 7                  60  24    0.0     37       16     77
# 8                  30  43   28.0     22       34    127
# 8                  30  33   18.0     12       24     87
# 9                 100  22   84.0     23       -9    120
# 9                 100  32   94.0     33        1    160
# 10                100  43  100.0     90       92    325
# 10                100  33   90.0     80       82    285

# %%
term = df.groupby(['Name', 'Term'])['Total'].sum().unstack()

term.plot.bar()
plt.xlabel('Students')
plt.ylabel('Result(Total Up)')
# plt.title('Country')
plt.show()

# %% [markdown]
# ## 3. Basic Statistics of Table

# %%
df.describe()
# Out:
#        StudentID       Term  Attendance         BM          BI      Maths  \
# count  20.000000  20.000000   20.000000  20.000000   20.000000  20.000000
# mean    5.500000   1.500000   72.700000  29.700000   55.500000  34.800000
# std     2.946898   0.512989   22.571757  24.525175   32.763105  30.365493
# min     1.000000   1.000000   30.000000   0.000000    0.000000   0.000000
# 25%     3.000000   1.000000   58.000000  15.500000   26.000000  11.500000
# 50%     5.500000   1.500000   71.000000  24.500000   61.500000  26.000000
# 75%     8.000000   2.000000  100.000000  33.500000   84.000000  39.500000
# max    10.000000   2.000000  100.000000  97.000000  100.000000  97.000000
#
#          Sejarah       Total
# count  20.000000   20.000000
# mean   51.200000  170.700000
# std    36.685864   75.577844
# min    -9.000000   37.000000
# 25%    14.750000  125.250000
# 50%    62.500000  164.000000
# 75%    82.500000  202.500000
# max    97.000000  325.000000

# %% [markdown]
# ### The top 3 and last 3 students each term

# %%
term1t = df[df['Term'] == 1].groupby(['StudentID','Name'])[['Total','Term']].sum().sort_values("Total", ascending=False).head(3)
term1l = df[df['Term'] == 1].groupby(['StudentID','Name'])[['Total','Term']].sum().sort_values("Total", ascending=False).tail(3)
term2t = df[df['Term'] == 2].groupby(['StudentID','Name'])[['Total','Term']].sum().sort_values("Total", ascending=False).head(3)
term2l = df[df['Term'] == 2].groupby(['StudentID','Name'])[['Total','Term']].sum().sort_values("Total", ascending=False).tail(3)
print("Top 3 students for 1st Term")
print(term1t)
print('')
print("Last 3 students for 1st Term")
print(term1l)
print('')
print("Top 3 students for 2nd Term")
print(term2t)
print('')
print("Last 3 students for 2nd Term")
print(term2t)
print('')
# Out:
# Top 3 students for 1st Term
#                    Total  Term
# StudentID Name
# 10        Ah Beng    285     1
# 1         Ali        259     1
# 2         Siti       170     1
#
# Last 3 students for 1st Term
#                    Total  Term
# StudentID Name
# 6         Mei Lin    110     1
# 8         Edward      87     1
# 7         Psy         37     1
#
# Top 3 students for 2nd Term
#                    Total  Term
# StudentID Name
# 10        Ah Beng    325     2
# 1         Ali        299     2
# 2         Siti       210     2
#
# Last 3 students for 2nd Term
#                    Total  Term
# StudentID Name
# 10        Ah Beng    325     2
# 1         Ali        299     2
# 2         Siti       210     2

# %% [markdown]
# ### Average Scores for each term

# %%
avg = df.groupby('Term')[['BI', 'BM', 'Maths', 'Sejarah', 'Total']].mean()
avg
# Out:
#         BI    BM  Maths  Sejarah  Total
# Term
# 1     51.0  25.7   31.2     46.2  153.1
# 2     60.0  33.7   38.4     56.2  188.3

# %% [markdown]
# ### Max score for each subject

# %%
term = df.groupby(['Name', 'Term'])['Total'].sum().unstack()

term.plot.bar()
plt.xlabel('Students')
plt.ylabel('Result(Total Up)')
# plt.title('Country')
plt.show()

# %% [markdown]
# ### Type Markdown and LaTeX:  𝛼2

# %%
# term = df[df['Term'] == 1]
# plt.figure(figsize = (15,8))
# plt.bar(term['Name'], term['Total'])
# plt.ticklabel_format(useOffset = False, style = 'plain', axis = 'y')
# plt.xlabel('Region')
# plt.ylabel('Death Rate')
# plt.show()

term1 = df[df['Term'] == 1]
term1 = term1[['Total','IncomeGroup']].set_index('IncomeGroup')
term1.plot(kind='bar')

plt.xlabel('Name')
plt.ylabel('Total')
plt.title('Total by Student and Income Group (Term 1)')
plt.xticks(rotation=90)
plt.show()

# %%
subs = df.groupby('Term')['BI','BM','Maths','Sejarah'].mean().reset_index().set_index('Term')
subs.plot(kind='bar')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6620\4166321717.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   subs = df.groupby('Term')['BI','BM','Maths','Sejarah'].mean().reset_index().set_index('Term')
# <Axes: xlabel='Term'>

# %%
subs = df[df['Term']==1].groupby(['Tuisyen'])['BI','BM','Maths','Sejarah'].mean().reset_index().set_index('Tuisyen')
subs.plot(kind='bar')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6620\651614195.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   subs = df[df['Term']==1].groupby(['Tuisyen'])['BI','BM','Maths','Sejarah'].mean().reset_index().set_index('Tuisyen')
# <Axes: xlabel='Tuisyen'>

# %% [markdown]
# ## 4. Replace IncomeGroup and Tuisyen to Numerical Value

# %%
income_mapping = {'B40': 1, 'M40': 2, 'T20': 3}
tuisyen_mapping = {'Yes': 0, 'No': 1}

df['IncomeGroup'] = df['IncomeGroup'].map(income_mapping)
df['Tuisyen'] = df['Tuisyen'].map(tuisyen_mapping)
df
# Out:
#     StudentID      Name  Term  IncomeGroup NonsenseData      School  Tuisyen  \
# 0           7       Psy     2            1         xvxc  SK Bestari        1
# 1           8    Edward     2            2           sf  SK Bestari        0
# 2           6   Mei Lin     2            2          dsf  SK Bestari        0
# 3           9  Miyazawa     2            3           df  SK Bestari        1
# 4           4  Letchumi     2            3         xvxc  SK Bestari        1
# 5           3     Muthu     2            3           sf  SK Bestari        0
# 6           5  Ah Chong     2            1          dsf  SK Bestari        0
# 7           2      Siti     2            2           df  SK Bestari        0
# 8           1       Ali     2            1         xvxc  SK Bestari        1
# 9          10   Ah Beng     2            3           sf  SK Bestari        1
# 10          7       Psy     1            1          dsf  SK Bestari        1
# 11          8    Edward     1            2           df  SK Bestari        0
# 12          6   Mei Lin     1            2         xvxc  SK Bestari        0
# 13          9  Miyazawa     1            3           sf  SK Bestari        1
# 14          4  Letchumi     1            3          dsf  SK Bestari        1
# 15          3     Muthu     1            3           df  SK Bestari        0
# 16          5  Ah Chong     1            1         xvxc  SK Bestari        0
# 17          2      Siti     1            2           sf  SK Bestari        0
# 18          1       Ali     1            1          dsf  SK Bestari        1
# 19         10   Ah Beng     1            3           df  SK Bestari        1
#
#     Attendance  BM     BI  Maths  Sejarah  Total
# 0           60  24    0.0     37       16     77
# 1           30  43   28.0     22       34    127
# 2           78   0   20.0     47       63    130
# 3          100  32   94.0     33        1    160
# 4           80  97   52.0     17       11    177
# 5           58  31   65.0      0       82    178
# 6           64  16   84.0      6       94    200
# 7           57  35   68.0     35       72    210
# 8          100  16   89.0     97       97    299
# 9          100  43  100.0     90       92    325
# 10          60  14    0.0     27        6     37
# 11          30  33   18.0     12       24     87
# 12          78  10   10.0     37       53    110
# 13         100  22   84.0     23       -9    120
# 14          80  87   42.0      7        1    137
# 15          58  21   55.0     10       72    158
# 16          64   6   74.0      4       84    168
# 17          57  25   58.0     25       62    170
# 18         100   6   79.0     87       87    259
# 19         100  33   90.0     80       82    285

# %% [markdown]
# ## 5. Check the correlation between income group, tuisyen and result

# %%
co = df[['IncomeGroup', 'Tuisyen','BM','BI','Maths','Sejarah', 'Total']].corr()
co
# Out:
#              IncomeGroup   Tuisyen        BM        BI     Maths   Sejarah  \
# IncomeGroup     1.000000  0.120386  0.565563  0.273317 -0.137483 -0.259916
# Tuisyen         0.120386  1.000000  0.322119  0.234863  0.506815 -0.357972
# BM              0.565563  0.322119  1.000000  0.028886 -0.219737 -0.427311
# BI              0.273317  0.234863  0.028886  1.000000  0.349795  0.449886
# Maths          -0.137483  0.506815 -0.219737  0.349795  1.000000  0.406545
# Sejarah        -0.259916 -0.357972 -0.427311  0.449886  0.406545  1.000000
# Total           0.129596  0.229420  0.045778  0.813588  0.681237  0.713688
#
#                 Total
# IncomeGroup  0.129596
# Tuisyen      0.229420
# BM           0.045778
# BI           0.813588
# Maths        0.681237
# Sejarah      0.713688
# Total        1.000000

# %%
plt.scatter(df['Attendance'], df['Total'])
plt.ylabel('Total Score')
plt.xlabel('Days of attendance')
plt.title('Days of attendance compared to Total Score')
# Out:
# Text(0.5, 1.0, 'Days of attendance compared to Total Score')

# %% [markdown]
# ## 6. Conclusion
#
# What is your finding?
